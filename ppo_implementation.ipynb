# %% [markdown]
# ### PPO AGENT:

# %% [markdown]
# #### Load the dataset and preprocess the dataframe in the required format.

# %% [markdown]
# Technical indicators created for the environment include:
#
# - RSI
# - MACD
# - Stoch_k
# - OBV
# - Upper_BB
# - ATR_1
# - ATR_2
# - ATR_5
# - ATR_10
# - ATR_20

# %%
import pandas as pd
import numpy as np
import talib as ta

class TechnicalIndicators:
    def __init__(self, data):
        self.data = data

    def add_momentum_indicators(self):
        self.data['RSI'] = ta.RSI(self.data['Close'], timeperiod=14)
        self.data['MACD'], self.data['MACD_signal'], self.data['MACD_hist'] = ta.MACD(self.data['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
        self.data['Stoch_k'], self.data['Stoch_d'] = ta.STOCH(self.data['High'], self.data['Low'], self.data['Close'],
                                                              fastk_period=14, slowk_period=3, slowd_period=3)

    def add_volume_indicators(self):
        self.data['OBV'] = ta.OBV(self.data['Close'], self.data['Volume'])

    def add_volatility_indicators(self):
        self.data['Upper_BB'], self.data['Middle_BB'], self.data['Lower_BB'] = ta.BBANDS(self.data['Close'], timeperiod=20)
        self.data['ATR_1'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=1)
        self.data['ATR_2'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=2)
        self.data['ATR_5'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=5)
        self.data['ATR_10'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=10)
        self.data['ATR_20'] = ta.ATR(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=20)

    def add_trend_indicators(self):
        self.data['ADX'] = ta.ADX(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['+DI'] = ta.PLUS_DI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['-DI'] = ta.MINUS_DI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=14)
        self.data['CCI'] = ta.CCI(self.data['High'], self.data['Low'], self.data['Close'], timeperiod=5)

    def add_other_indicators(self):
        self.data['DLR'] = np.log(self.data['Close'] / self.data['Close'].shift(1))
        self.data['TWAP'] = self.data['Close'].expanding().mean()
        self.data['VWAP'] = (self.data['Volume'] * (self.data['High'] + self.data['Low']) / 2).cumsum() / self.data['Volume'].cumsum()

    def add_all_indicators(self):
        self.add_momentum_indicators()
        self.add_volume_indicators()
        self.add_volatility_indicators()
        self.add_trend_indicators()
        self.add_other_indicators()
        return self.data

# %%
data = pd.read_csv('xnas-itch-20230703.tbbo.csv')

# Preprocessing to create necessary columns
data['price']=data['price']/1e9
data['bid_px_00']=data['bid_px_00']/1e9
data['ask_px_00']=data['ask_px_00']/1e9

data['Close'] = data['price']
data['Volume'] = data['size']
data['High'] = data[['bid_px_00', 'ask_px_00']].max(axis=1)
data['Low'] = data[['bid_px_00', 'ask_px_00']].min(axis=1)
data['Open'] = data['Close'].shift(1).fillna(data['Close'])


ti = TechnicalIndicators(data)
df_with_indicators = ti.add_all_indicators()
market_features_df = df_with_indicators[35:]

# %% [markdown]
# Checking the dataset:

# %%
# Show all columns in pandas
pd.set_option('display.max_columns', None)

market_features_df.head(35)
# Out:
#                 ts_recv             ts_event  rtype  publisher_id  \
# 35  1688371214386057385  1688371214385893078      1             2
# 36  1688371214386063777  1688371214385899379      1             2
# 37  1688371215804852019  1688371215804687301      1             2
# 38  1688371219671476629  1688371219671312224      1             2
# 39  1688371223368835585  1688371223368671235      1             2
# 40  1688371229849940201  1688371229849775570      1             2
# 41  1688371230451172473  1688371230451005195      1             2
# 42  1688371230451172473  1688371230451005195      1             2
# 43  1688371230451172473  1688371230451005195      1             2
# 44  1688371230451995982  1688371230451829005      1             2
# 45  1688371230451995982  1688371230451829005      1             2
# 46  1688371230451995982  1688371230451829005      1             2
# 47  1688371230451995982  1688371230451829005      1             2
# 48  1688371230566546422  1688371230566381995      1             2
# 49  1688371237858109689  1688371237857944791      1             2
# 50  1688371242324266534  1688371242324101963      1             2
# 51  1688371247317894640  1688371247317729998      1             2
# 52  1688371257325756491  1688371257325590403      1             2
# 53  1688371257325756491  1688371257325590403      1             2
# 54  1688371259762706298  1688371259762541862      1             2
# 55  1688371259998644855  1688371259998480243      1             2
# 56  1688371262030749190  1688371262030585068      1             2
# 57  1688371262738878803  1688371262738714506      1             2
# 58  1688371262738976817  1688371262738812696      1             2
# 59  1688371262739005935  1688371262738841844      1             2
# 60  1688371262739229179  1688371262739065129      1             2
# 61  1688371262739239338  1688371262739074592      1             2
# 62  1688371270151139658  1688371270150974638      1             2
# 63  1688371271298128899  1688371271297964469      1             2
# 64  1688371271609555288  1688371271609390022      1             2
# 65  1688371272249175548  1688371272249009974      1             2
# 66  1688371272249760640  1688371272249596259      1             2
# 67  1688371272250210772  1688371272250045693      1             2
# 68  1688371272250210772  1688371272250045693      1             2
# 69  1688371272377490201  1688371272377325167      1             2
#
#     instrument_id action side  depth   price  size  flags  ts_in_delta  \
# 35             32      T    N      0  194.05    50    130       164307
# 36             32      T    N      0  194.05    50    130       164398
# 37             32      T    B      0  194.21    10    130       164718
# 38             32      T    N      0  194.14    10    130       164405
# 39             32      T    B      0  194.13    10    130       164350
# 40             32      T    B      0  194.13   100    130       164631
# 41             32      T    N      0  194.02    10      0       167278
# 42             32      T    A      0  194.01     1      0       167278
# 43             32      T    A      0  194.01   100    130       167278
# 44             32      T    A      0  194.00  3075      0       166977
# 45             32      T    A      0  194.00     4      0       166977
# 46             32      T    A      0  194.00     5      0       166977
# 47             32      T    A      0  194.00    16    130       166977
# 48             32      T    N      0  194.09    10    130       164427
# 49             32      T    B      0  194.12    10    130       164898
# 50             32      T    B      0  194.15    10    130       164571
# 51             32      T    B      0  194.10    10    130       164642
# 52             32      T    A      0  194.10     1      0       166088
# 53             32      T    A      0  194.10     1    130       166088
# 54             32      T    B      0  194.12    50    130       164436
# 55             32      T    B      0  194.12     4    130       164612
# 56             32      T    B      0  194.12     3    130       164122
# 57             32      T    B      0  194.12    75    130       164297
# 58             32      T    B      0  194.12    18    130       164121
# 59             32      T    B      0  194.12    10    130       164091
# 60             32      T    B      0  194.12    75    130       164050
# 61             32      T    B      0  194.12     9    130       164746
# 62             32      T    B      0  194.18     1    130       165020
# 63             32      T    B      0  194.18     2    130       164430
# 64             32      T    B      0  194.18     1    130       165266
# 65             32      T    B      0  194.18     6    130       165574
# 66             32      T    B      0  194.20     1    130       164381
# 67             32      T    B      0  194.26     9      0       165079
# 68             32      T    B      0  194.26    50    130       165079
# 69             32      T    N      0  194.28     1    130       165034
#
#     sequence  bid_px_00  ask_px_00  bid_sz_00  ask_sz_00  bid_ct_00  \
# 35    326232     194.00     194.30       3101         19          4
# 36    326233     194.00     194.30       3101         19          4
# 37    328131     194.00     194.21       3101         29          4
# 38    331406     194.00     194.16       3101        400          4
# 39    334235     194.00     194.13       3101        400          4
# 40    339055     194.01     194.13        101        390          2
# 41    339547     194.01     194.16        101        400          2
# 42    339548     194.01     194.16        101        400          2
# 43    339549     194.01     194.16        100        400          1
# 44    339553     194.00     194.16       3119        400          5
# 45    339554     194.00     194.16         44        400          4
# 46    339555     194.00     194.16         40        400          3
# 47    339556     194.00     194.16         35        400          2
# 48    339623     194.00     194.16         19        400          2
# 49    346965     194.02     194.12         80        400          1
# 50    350459     194.02     194.15        180        400          2
# 51    354918     194.06     194.10        100         10          1
# 52    363515     194.10     194.12        101        244          2
# 53    363516     194.10     194.12        100        244          1
# 54    366351     194.10     194.12         99        244          1
# 55    367018     194.10     194.12         99        194          1
# 56    370717     194.11     194.12        200        190          1
# 57    372529     194.11     194.12        200        187          1
# 58    372534     194.11     194.12        200        112          1
# 59    372547     194.11     194.12        200         94          1
# 60    372566     194.11     194.12        200         84          1
# 61    372567     194.11     194.12        200          9          1
# 62    378624     194.11     194.18        200         10          1
# 63    379579     194.12     194.18          1          9          1
# 64    380000     194.12     194.18          3          7          1
# 65    380446     194.15     194.18         99          6          1
# 66    380449     194.15     194.20         99          1          1
# 67    380450     194.15     194.26         99         59          1
# 68    380451     194.15     194.26         99         50          1
# 69    380534     194.15     194.29         99        400          1
#
#     ask_ct_00 symbol   Close  Volume    High     Low    Open        RSI  \
# 35         10   AAPL  194.05      50  194.30  194.00  194.05  54.544543
# 36         10   AAPL  194.05      50  194.30  194.00  194.05  54.544543
# 37          1   AAPL  194.21      10  194.21  194.00  194.05  85.890753
# 38          1   AAPL  194.14      10  194.16  194.00  194.21  64.827662
# 39          1   AAPL  194.13      10  194.13  194.00  194.14  62.470772
# 40          1   AAPL  194.13     100  194.13  194.01  194.13  62.470772
# 41          1   AAPL  194.02      10  194.16  194.01  194.13  42.676806
# 42          1   AAPL  194.01       1  194.16  194.01  194.02  41.392784
# 43          1   AAPL  194.01     100  194.16  194.01  194.01  41.392784
# 44          1   AAPL  194.00    3075  194.16  194.00  194.01  39.997126
# 45          1   AAPL  194.00       4  194.16  194.00  194.00  39.997126
# 46          1   AAPL  194.00       5  194.16  194.00  194.00  39.997126
# 47          1   AAPL  194.00      16  194.16  194.00  194.00  39.997126
# 48          1   AAPL  194.09      10  194.16  194.00  194.00  57.389307
# 49          1   AAPL  194.12      10  194.12  194.02  194.09  61.405134
# 50          1   AAPL  194.15      10  194.15  194.02  194.12  64.961352
# 51          1   AAPL  194.10      10  194.10  194.06  194.15  55.742466
# 52          1   AAPL  194.10       1  194.12  194.10  194.10  55.742466
# 53          1   AAPL  194.10       1  194.12  194.10  194.10  55.742466
# 54          1   AAPL  194.12      50  194.12  194.10  194.10  58.672524
# 55          1   AAPL  194.12       4  194.12  194.10  194.12  58.672524
# 56          1   AAPL  194.12       3  194.12  194.11  194.12  58.672524
# 57          1   AAPL  194.12      75  194.12  194.11  194.12  58.672524
# 58          1   AAPL  194.12      18  194.12  194.11  194.12  58.672524
# 59          1   AAPL  194.12      10  194.12  194.11  194.12  58.672524
# 60          1   AAPL  194.12      75  194.12  194.11  194.12  58.672524
# 61          1   AAPL  194.12       9  194.12  194.11  194.12  58.672524
# 62          1   AAPL  194.18       1  194.18  194.11  194.12  69.597068
# 63          1   AAPL  194.18       2  194.18  194.12  194.18  69.597068
# 64          1   AAPL  194.18       1  194.18  194.12  194.18  69.597068
# 65          1   AAPL  194.18       6  194.18  194.15  194.18  69.597068
# 66          1   AAPL  194.20       1  194.20  194.15  194.18  72.818542
# 67          2   AAPL  194.26       9  194.26  194.15  194.20  79.750541
# 68          1   AAPL  194.26      50  194.26  194.15  194.26  79.750541
# 69          1   AAPL  194.28       1  194.29  194.15  194.26  81.567778
#
#         MACD  MACD_signal  MACD_hist       Stoch_k     Stoch_d     OBV  \
# 35  0.006271    -0.003130   0.009401  5.252525e+01   61.952862  -266.0
# 36  0.007108    -0.001082   0.008190  3.838384e+01   52.525253  -266.0
# 37  0.020446     0.003223   0.017223  4.040404e+01   43.771044  -256.0
# 38  0.025079     0.007594   0.017484  4.949495e+01   42.760943  -266.0
# 39  0.027625     0.011601   0.016025  5.757576e+01   49.158249  -276.0
# 40  0.029305     0.015141   0.014164  4.949495e+01   52.188552  -276.0
# 41  0.021513     0.016416   0.005097  3.454545e+01   47.205387  -286.0
# 42  0.014365     0.016006  -0.001641  1.949495e+01   34.511785  -287.0
# 43  0.008601     0.014525  -0.005924  4.444444e+00   19.494949  -287.0
# 44  0.003189     0.012257  -0.009069  2.222222e+00    8.720539 -3362.0
# 45 -0.001087     0.009588  -0.010676  1.111111e+00    2.592593 -3362.0
# 46 -0.004425     0.006786  -0.011211 -4.736952e-15    1.111111 -3362.0
# 47 -0.006990     0.004030  -0.011021 -4.736952e-15    0.370370 -3362.0
# 48 -0.001741     0.002876  -0.004617  1.000000e+01    3.333333 -3352.0
# 49  0.004785     0.003258   0.001527  2.333333e+01   11.111111 -3342.0
# 50  0.012237     0.005054   0.007183  4.714286e+01   26.825397 -3332.0
# 51  0.013947     0.006833   0.007115  5.797619e+01   42.817460 -3342.0
# 52  0.015128     0.008492   0.006636  6.547619e+01   56.865079 -3342.0
# 53  0.015881     0.009969   0.005911  6.250000e+01   61.984127 -3342.0
# 54  0.017885     0.011553   0.006332  6.666667e+01   64.880952 -3292.0
# 55  0.019251     0.013092   0.006159  7.083333e+01   66.666667 -3292.0
# 56  0.020103     0.014494   0.005608  7.500000e+01   70.833333 -3292.0
# 57  0.020540     0.015704   0.004837  7.500000e+01   73.611111 -3292.0
# 58  0.020649     0.016693   0.003957  7.500000e+01   75.000000 -3292.0
# 59  0.020499     0.017454   0.003045  7.500000e+01   75.000000 -3292.0
# 60  0.020148     0.017993   0.002155  7.500000e+01   75.000000 -3292.0
# 61  0.019644     0.018323   0.001321  7.500000e+01   75.000000 -3292.0
# 62  0.023811     0.019421   0.004390  8.333333e+01   77.777778 -3291.0
# 63  0.026804     0.020897   0.005907  9.166667e+01   83.333333 -3291.0
# 64  0.028844     0.022487   0.006357  1.000000e+02   91.666667 -3291.0
# 65  0.030113     0.024012   0.006101  1.000000e+02   97.222222 -3291.0
# 66  0.032360     0.025682   0.006679  1.000000e+02  100.000000 -3290.0
# 67  0.038538     0.028253   0.010285  1.000000e+02  100.000000 -3281.0
# 68  0.042939     0.031190   0.011749  1.000000e+02  100.000000 -3281.0
# 69  0.047493     0.034451   0.013043  9.814815e+01   99.382716 -3280.0
#
#       Upper_BB  Middle_BB    Lower_BB  ATR_1     ATR_2     ATR_5    ATR_10  \
# 35  194.065621   194.0170  193.968379   0.30  0.175078  0.098615  0.075141
# 36  194.068990   194.0200  193.971010   0.30  0.237539  0.138892  0.097627
# 37  194.125889   194.0305  193.935111   0.21  0.223770  0.153114  0.108864
# 38  194.142928   194.0375  193.932072   0.21  0.216885  0.164491  0.118978
# 39  194.155247   194.0440  193.932753   0.14  0.178442  0.159593  0.121080
# 40  194.165821   194.0505  193.935179   0.12  0.149221  0.151674  0.120972
# 41  194.165390   194.0515  193.937610   0.15  0.149611  0.151339  0.123875
# 42  194.165066   194.0520  193.938934   0.15  0.149805  0.151071  0.126487
# 43  194.164727   194.0525  193.940273   0.15  0.149903  0.150857  0.128839
# 44  194.164727   194.0525  193.940273   0.16  0.154951  0.152686  0.131955
# 45  194.164727   194.0525  193.940273   0.16  0.157476  0.154149  0.134759
# 46  194.164727   194.0525  193.940273   0.16  0.158738  0.155319  0.137283
# 47  194.164727   194.0525  193.940273   0.16  0.159369  0.156255  0.139555
# 48  194.167653   194.0570  193.946347   0.16  0.159684  0.157004  0.141600
# 49  194.174425   194.0605  193.946575   0.10  0.129842  0.145603  0.137440
# 50  194.185746   194.0655  193.945254   0.13  0.129921  0.142483  0.136696
# 51  194.188930   194.0680  193.947070   0.09  0.109961  0.131986  0.132026
# 52  194.191904   194.0705  193.949096   0.02  0.064980  0.109589  0.120823
# 53  194.194672   194.0730  193.951328   0.02  0.042490  0.091671  0.110741
# 54  194.199345   194.0765  193.953655   0.02  0.031245  0.077337  0.101667
# 55  194.203612   194.0800  193.956388   0.02  0.025623  0.065870  0.093500
# 56  194.207480   194.0835  193.959520   0.01  0.017811  0.054696  0.085150
# 57  194.190158   194.0790  193.967842   0.01  0.013906  0.045756  0.077635
# 58  194.187289   194.0780  193.968711   0.01  0.011953  0.038605  0.070872
# 59  194.185920   194.0775  193.969080   0.01  0.010976  0.032884  0.064785
# 60  194.184536   194.0770  193.969464   0.01  0.010488  0.028307  0.059306
# 61  194.187754   194.0820  193.976246   0.01  0.010244  0.024646  0.054375
# 62  194.199031   194.0905  193.981969   0.07  0.040122  0.033717  0.055938
# 63  194.207609   194.0990  193.990391   0.06  0.050061  0.038973  0.056344
# 64  194.212038   194.1080  194.003962   0.06  0.055031  0.043179  0.056710
# 65  194.212937   194.1170  194.021063   0.03  0.042515  0.040543  0.054039
# 66  194.213279   194.1270  194.040721   0.05  0.046258  0.042434  0.053635
# 67  194.224143   194.1400  194.055857   0.11  0.078129  0.055947  0.059271
# 68  194.244265   194.1485  194.052735   0.11  0.094064  0.066758  0.064344
# 69  194.267003   194.1565  194.045997   0.14  0.117032  0.081406  0.071910
#
#       ATR_20        ADX        +DI       -DI         CCI       DLR  \
# 35  0.072403  97.257397  30.435801  0.196362  166.666667  0.000000
# 36  0.083783  97.361721  22.989295  0.148320   83.333333  0.000000
# 37  0.090094  97.458593  19.409454  0.125224   79.268293  0.000824
# 38  0.096089  97.548546  16.622008  0.107240   -3.205128 -0.000360
# 39  0.098285  97.632074  15.068361  0.097216 -113.095238 -0.000052
# 40  0.099370  97.709636  13.871534  0.089495  -64.102564  0.000000
# 41  0.101902  97.793820  14.463498  0.080850 -113.425926 -0.000567
# 42  0.104307  97.871992  13.100725  0.073232  -90.909091 -0.000052
# 43  0.106591  97.944580  11.893862  0.066486  -61.224490  0.000000
# 44  0.109262  97.267563  10.755675  0.658220  -81.081081 -0.000052
# 45  0.111799  96.638905   9.750792  0.596723  -83.333333  0.000000
# 46  0.114209  96.055151   8.859404  0.542173  -55.555556  0.000000
# 47  0.116498  95.513093   8.065375  0.493580  -41.666667  0.000000
# 48  0.118673  95.009754   7.355430  0.450133  166.666667  0.000464
# 49  0.117740  94.542368   6.944020  0.424956   90.643275  0.000155
# 50  0.118353  94.270606   8.115584  0.394096  107.142857  0.000155
# 51  0.116935  94.018256   7.698755  0.373855   18.518519 -0.000258
# 52  0.112088  93.871355   8.819513  0.369315   83.333333  0.000000
# 53  0.107484  93.734948   8.705674  0.364548   55.555556  0.000000
# 54  0.103110  93.608283   8.586320  0.359550   89.743590  0.000103
# 55  0.098954  93.490667   8.461391  0.354319   71.428571  0.000000
# 56  0.094507  93.381451   8.395616  0.351564   95.238095  0.000000
# 57  0.090281  93.280037   8.325915  0.348646   83.333333  0.000000
# 58  0.086267  93.185866   8.252135  0.345556   55.555556  0.000000
# 59  0.082454  93.098422   8.174129  0.342290   41.666667  0.000000
# 60  0.078831  93.017224   8.091754  0.338840    0.000000  0.000000
# 61  0.075390  92.941826   8.004880  0.335203    0.000000  0.000000
# 62  0.075120  93.132535  13.823288  0.310105  166.666667  0.000309
# 63  0.074364  93.309621  12.929663  0.290057   88.888889  0.000000
# 64  0.073646  93.474059  12.088099  0.271178   59.210526  0.000000
# 65  0.071464  93.626751  11.678789  0.261996   80.246914  0.000000
# 66  0.070390  93.821556  13.301406  0.246985  135.416667  0.000103
# 67  0.072371  94.094475  18.230801  0.217466  152.777778  0.000309
# 68  0.074252  94.347900  16.151871  0.192668   83.333333  0.000000
# 69  0.077540  94.611861  16.865129  0.166625   85.106383  0.000103
#
#           TWAP        VWAP
# 35  194.020000  194.021894
# 36  194.020811  194.025188
# 37  194.025789  194.025596
# 38  194.028718  194.025873
# 39  194.031250  194.026071
# 40  194.033659  194.028188
# 41  194.033333  194.028460
# 42  194.032791  194.028488
# 43  194.032273  194.031073
# 44  194.031556  194.059670
# 45  194.030870  194.059686
# 46  194.030213  194.059705
# 47  194.029583  194.059766
# 48  194.030816  194.059805
# 49  194.032600  194.059824
# 50  194.034902  194.059871
# 51  194.036154  194.059909
# 52  194.037358  194.059918
# 53  194.038519  194.059928
# 54  194.040000  194.060393
# 55  194.041429  194.060430
# 56  194.042807  194.060461
# 57  194.044138  194.061210
# 58  194.045424  194.061386
# 59  194.046667  194.061484
# 60  194.047869  194.062206
# 61  194.049032  194.062291
# 62  194.051111  194.062306
# 63  194.053125  194.062337
# 64  194.055077  194.062353
# 65  194.056970  194.062463
# 66  194.059104  194.062483
# 67  194.062059  194.062713
# 68  194.064928  194.063974
# 69  194.068000  194.064001

# %%
df_with_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59271 entries, 0 to 59270
# Data columns (total 47 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ts_recv        59271 non-null  int64
#  1   ts_event       59271 non-null  int64
#  2   rtype          59271 non-null  int64
#  3   publisher_id   59271 non-null  int64
#  4   instrument_id  59271 non-null  int64
#  5   action         59271 non-null  object
#  6   side           59271 non-null  object
#  7   depth          59271 non-null  int64
#  8   price          59271 non-null  float64
#  9   size           59271 non-null  int64
#  10  flags          59271 non-null  int64
#  11  ts_in_delta    59271 non-null  int64
#  12  sequence       59271 non-null  int64
#  13  bid_px_00      59271 non-null  float64
#  14  ask_px_00      59271 non-null  float64
#  15  bid_sz_00      59271 non-null  int64
#  16  ask_sz_00      59271 non-null  int64
#  17  bid_ct_00      59271 non-null  int64
#  18  ask_ct_00      59271 non-null  int64
#  19  symbol         59271 non-null  object
#  20  Close          59271 non-null  float64
#  21  Volume         59271 non-null  int64
#  22  High           59271 non-null  float64
#  23  Low            59271 non-null  float64
#  24  Open           59271 non-null  float64
#  25  RSI            59257 non-null  float64
#  26  MACD           59238 non-null  float64
#  27  MACD_signal    59238 non-null  float64
#  28  MACD_hist      59238 non-null  float64
#  29  Stoch_k        59254 non-null  float64
#  30  Stoch_d        59254 non-null  float64
#  31  OBV            59271 non-null  float64
#  32  Upper_BB       59252 non-null  float64
#  33  Middle_BB      59252 non-null  float64
#  34  Lower_BB       59252 non-null  float64
#  35  ATR_1          59270 non-null  float64
#  36  ATR_2          59269 non-null  float64
#  37  ATR_5          59266 non-null  float64
#  38  ATR_10         59261 non-null  float64
#  39  ATR_20         59251 non-null  float64
#  40  ADX            59244 non-null  float64
#  41  +DI            59257 non-null  float64
#  42  -DI            59257 non-null  float64
#  43  CCI            59267 non-null  float64
#  44  DLR            59270 non-null  float64
#  45  TWAP           59271 non-null  float64
#  46  VWAP           59271 non-null  float64
# dtypes: float64(29), int64(15), object(3)
# memory usage: 21.3+ MB

# %% [markdown]
# #### Create the Trading Environment class for the PPO Agent

# %%
import gym
from gym import spaces
import numpy as np
import pandas as pd

class TradingEnvironment(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, data, daily_trading_limit):
        super(TradingEnvironment, self).__init__()
        self.data = data
        self.daily_trading_limit = daily_trading_limit
        self.current_step = 0

        # Extract state columns
        self.state_columns = ['Close', 'Volume', 'RSI', 'MACD', 'MACD_signal', 'MACD_hist', 'Stoch_k', 'Stoch_d',
                              'OBV', 'Upper_BB', 'Middle_BB', 'Lower_BB', 'ATR_1', 'ADX', '+DI', '-DI', 'CCI']

        # Initialize balance, shares held, and total shares traded
        self.balance = 10_000_000.0  # $10 million
        self.shares_held = 0
        self.total_shares_traded = 0

        # Define action space: [Hold, Buy, Sell]
        self.action_space = spaces.Discrete(3)

        # Define observation space based on state columns
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(len(self.state_columns),), dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        self.balance = 10_000_000.0  # $10 million
        self.shares_held = 0
        self.total_shares_traded = 0
        self.cumulative_reward = 0
        self.trades = []
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.state_columns].iloc[self.current_step].values

    def step(self, action):
        expected_price = self.data.iloc[self.current_step]['ask_px_00']
        actual_price = self.data.iloc[self.current_step]['price']
        transaction_time = self.data.iloc[self.current_step]['ts_in_delta']
        self._take_action(action)
        reward = 0
        
        if self.current_step >= len(self.data) - 1:
            self.current_step = 0
        if action != 0:
            transaction_cost= self._calculate_transaction_cost(self.data.iloc[self.current_step]['Volume'], 0.3, self.data['Volume'].mean())
            reward = self._calculate_reward(expected_price, actual_price, transaction_time, transaction_cost)
            self.cumulative_reward += reward
            if self.trades:
                self.trades[-1]['reward'] = reward
                self.trades[-1]['transaction_cost'] = transaction_cost
                self.trades[-1]['slippage'] = expected_price - actual_price
                self.trades[-1]['time_penalty'] = 100*transaction_time/1e9
        done = self.current_step == len(self.data) - 1
        obs = self._next_observation()
        info = {
        'step': self.current_step,
        'action': action,
        'price': actual_price,
        'shares': self.trades[-1]['shares'] if self.trades else 0
    }
        self.current_step += 1

        return obs, reward, done, info

    def _take_action(self, action):
        current_price = self.data.iloc[self.current_step]['Close']
        current_time = pd.to_datetime(self.data.iloc[self.current_step]['ts_event'])
        trade_info = {'step': self.current_step, 'timestamp': current_time, 'action': action, 'price': current_price, 'shares': 0, 'reward': 0, 'transaction_cost': 0, 'slippage': 0, 'time_penalty': 0}

        if action == 1: # and self.total_shares_traded < self.daily_trading_limit:  # Buy
            shares_bought = (self.balance * np.random.uniform(0.001, 0.005)) // current_price
            self.balance -= shares_bought * current_price
            self.shares_held += shares_bought
            self.total_shares_traded += shares_bought
            trade_info['shares'] = shares_bought
            if(shares_bought>0):
                self.trades.append(trade_info)
        elif action == 2: # and self.total_shares_traded < self.daily_trading_limit:  # Sell
            shares_sold = min((self.balance * np.random.uniform(0.001, 0.005)) // current_price, self.shares_held)
            self.balance += shares_sold * current_price
            self.shares_held -= shares_sold
            self.total_shares_traded -= shares_sold
            trade_info['shares'] = shares_sold
            if(shares_sold>0):
                self.trades.append(trade_info)

    def _calculate_reward(self, expected_price, actual_price, transaction_time, transaction_cost):
        slippage = expected_price - actual_price
        time_penalty = 100*transaction_time/1e9
        reward = - (slippage + time_penalty + transaction_cost)
        return reward
    
    def _calculate_transaction_cost(self, volume, volatility, daily_volume):
        return volatility * np.sqrt(volume / daily_volume)
    
    def run(self):
        self.reset()
        for _ in range(len(self.data)):
            self.step()
        return self.cumulative_reward, self.trades

    def render(self, mode='human', close=False):
        print(f'Step: {self.current_step}')
        print(f'Balance: {self.balance}')
        print(f'Shares held: {self.shares_held}')
        print(f'Total shares traded: {self.total_shares_traded}')
        print(f'Total portfolio value: {self.balance + self.shares_held * self.data.iloc[self.current_step]["Close"]}')
        print(f'Cumulative reward: {self.cumulative_reward}')
        self.print_trades()

    def print_trades(self):
        # download all trades in a pandas dataframe using .csv
        trades_df = pd.DataFrame(self.trades)
        # Save a csv
        trades_df.to_csv('trades_ppo.csv', index=False)
        for trade in self.trades:
            print(f"Step: {trade['step']}, Timestamp: {trade['timestamp']}, Action: {trade['action']}, Price: {trade['price']}, Shares: {trade['shares']}, Reward: {trade['reward']}, Transaction Cost: {trade['transaction_cost']}, Slippage: {trade['slippage']}, Time Penalty: {trade['time_penalty']}")

# %% [markdown]
# #### Train the PPO Agent with the environment and for different tickers.

# %%
# Define the daily trading limit (total number of shares to trade per day)
daily_trading_limit = 1000

ticker = 'AAPL'  # Specify the ticker you want to trade
ticker_data = market_features_df[market_features_df['symbol'] == ticker]

env = TradingEnvironment(ticker_data, daily_trading_limit)  # Adjust window_size if needed

# %%
import pandas as pd
from stable_baselines3 import PPO

# Define the daily trading limit (total number of shares to trade per day)
daily_trading_limit = 1000

ticker = 'AAPL'  # Specify the ticker you want to trade
ticker_data = market_features_df[market_features_df['symbol'] == ticker]

# Create the trading environment
env = TradingEnvironment(ticker_data, daily_trading_limit)  # Adjust window_size if needed

# Define the best hyperparameters
best_hyperparameters = {'learning_rate': 0.0009931989008886031,'n_steps': 512,'batch_size': 128, 'gamma': 0.9916829193042708,'clip_range': 0.21127653449387027,'n_epochs': 6} # type: ignore

# Create the RL model with the best hyperparameters
model = PPO('MlpPolicy', env, verbose=1, **best_hyperparameters)

# Train the model
model.learn(total_timesteps=10000)

# Save the model
model.save("trading_agent")

# Evaluate the model
obs = env.reset()
for _ in range(len(ticker_data)):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        break

# Render the final state
env.render()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ----------------------------
# | time/              |     |
# |    fps             | 737 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 512 |
# ----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 2          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 1024       |
# | train/                  |            |
# |    approx_kl            | 0.01244005 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.211      |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -0.151     |
# |    learning_rate        | 0.000993   |
# |    loss                 | 0.187      |
# |    n_updates            | 6          |
# |    policy_gradient_loss | -0.0166    |
# |    value_loss           | 0.956      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.018587355 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0292      |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0436      |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 0.564       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.023351423 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | -0.039      |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.249       |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.0078     |
# |    value_loss           | 0.78        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 732        |
# |    iterations           | 5          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.03466575 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.211      |
# |    entropy_loss         | -0.853     |
# |    explained_variance   | -0.0473    |
# |    learning_rate        | 0.000993   |
# |    loss                 | 0.0573     |
# |    n_updates            | 24         |
# |    policy_gradient_loss | -0.0151    |
# |    value_loss           | 0.302      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.049096745 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.716      |
# |    explained_variance   | 0.00814     |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0356      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.172       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.052710466 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | -0.00394    |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.0137      |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.034995437 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.248      |
# |    explained_variance   | -0.00593    |
# |    learning_rate        | 0.000993    |
# |    loss                 | -0.00724    |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 0.0523      |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 728           |
# |    iterations           | 9             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 0.00017364987 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.211         |
# |    entropy_loss         | -0.458        |
# |    explained_variance   | 0.483         |
# |    learning_rate        | 0.000993      |
# |    loss                 | 0.672         |
# |    n_updates            | 48            |
# |    policy_gradient_loss | 0.000242      |
# |    value_loss           | 2.18          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 10          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.010535952 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.699      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.547       |
# |    n_updates            | 54          |
# |    policy_gradient_loss | -0.000251   |
# |    value_loss           | 5.63        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 11           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0043349355 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -0.611       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.473        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 0.00105      |
# |    value_loss           | 7.88         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 718           |
# |    iterations           | 12            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00049935386 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.211         |
# |    entropy_loss         | -0.609        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.000993      |
# |    loss                 | 0.251         |
# |    n_updates            | 66            |
# |    policy_gradient_loss | -0.000308     |
# |    value_loss           | 3.13          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 13           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0036011753 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -0.65        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.25         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000632    |
# |    value_loss           | 2.63         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 14          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009753858 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.327       |
# |    n_updates            | 78          |
# |    policy_gradient_loss | -9.04e-05   |
# |    value_loss           | 1.09        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 15          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.013613646 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.146       |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 1.09        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 710        |
# |    iterations           | 16         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00381349 |
# |    clip_fraction        | 0.0335     |
# |    clip_range           | 0.211      |
# |    entropy_loss         | -0.688     |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.000993   |
# |    loss                 | 0.25       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00134   |
# |    value_loss           | 0.821      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 17           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0044520926 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.097        |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00471     |
# |    value_loss           | 0.617        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 18           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0058448017 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.0488       |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 0.216        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 19           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0026287332 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.211        |
# |    entropy_loss         | -0.454       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.000993     |
# |    loss                 | 0.0785       |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000761    |
# |    value_loss           | 0.866        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 20          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008468795 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.211       |
# |    entropy_loss         | -0.395      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.000993    |
# |    loss                 | 0.103       |
# |    n_updates            | 114         |
# |    policy_gradient_loss | -0.000999   |
# |    value_loss           | 0.324       |
# -----------------------------------------
# Step: 1
# Balance: 38263.34999998723
# Shares held: 51411.0
# Total shares traded: 51411.0
# Total portfolio value: 10014567.899999987
# Cumulative reward: -11986.383617469794
# Step: 16, Timestamp: 2023-07-03 08:00:47.317729998, Action: 1, Price: 194.1, Shares: 126.0, Reward: -0.09678041803554471, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0164642
# Step: 19, Timestamp: 2023-07-03 08:00:59.762541862, Action: 2, Price: 194.12, Shares: 82.0, Reward: -0.19603612322317263, Transaction Cost: 0.17959252322317262, Slippage: 0.0, Time Penalty: 0.0164436
# Step: 20, Timestamp: 2023-07-03 08:00:59.998480243, Action: 2, Price: 194.12, Shares: 44.0, Reward: -0.08323204241218188, Transaction Cost: 0.056792142412190966, Slippage: 0.009999999999990905, Time Penalty: 0.0164399
# Step: 63, Timestamp: 2023-07-03 08:03:01.173535444, Action: 1, Price: 194.2, Shares: 176.0, Reward: -0.05235370464463453, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0164352
# Step: 72, Timestamp: 2023-07-03 08:03:30.071432879, Action: 2, Price: 194.15, Shares: 176.0, Reward: -0.25626792322317493, Transaction Cost: 0.17959252322317262, Slippage: 0.060000000000002274, Time Penalty: 0.0166754
# Step: 85, Timestamp: 2023-07-03 08:04:20.682195881, Action: 1, Price: 194.18, Shares: 115.0, Reward: -0.16699161803553791, Transaction Cost: 0.08031621803554471, Slippage: 0.06999999999999318, Time Penalty: 0.0166754
# Step: 89, Timestamp: 2023-07-03 08:04:22.775930851, Action: 2, Price: 194.25, Shares: 115.0, Reward: -0.15321794241217507, Transaction Cost: 0.056792142412190966, Slippage: 0.07999999999998408, Time Penalty: 0.0164258
# Step: 96, Timestamp: 2023-07-03 08:04:54.138834554, Action: 1, Price: 194.15, Shares: 142.0, Reward: -0.16238360464461976, Transaction Cost: 0.03591850464463453, Slippage: 0.10999999999998522, Time Penalty: 0.0164651
# Step: 112, Timestamp: 2023-07-03 08:05:28.625249690, Action: 2, Price: 194.15, Shares: 142.0, Reward: -0.25849890928925656, Transaction Cost: 0.07183700928926906, Slippage: 0.1699999999999875, Time Penalty: 0.0166619
# Step: 172, Timestamp: 2023-07-03 08:07:22.378410301, Action: 1, Price: 194.16, Shares: 148.0, Reward: -0.28053288204300664, Transaction Cost: 0.25398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0165507
# Step: 174, Timestamp: 2023-07-03 08:07:23.809281857, Action: 2, Price: 194.16, Shares: 148.0, Reward: -0.3204599820429987, Transaction Cost: 0.25398218204301576, Slippage: 0.04999999999998295, Time Penalty: 0.0164778
# Step: 220, Timestamp: 2023-07-03 08:09:23.513596182, Action: 1, Price: 194.05, Shares: 100.0, Reward: -0.18484697612859524, Transaction Cost: 0.09836687612860205, Slippage: 0.06999999999999318, Time Penalty: 0.0164801
# Step: 222, Timestamp: 2023-07-03 08:09:29.194412216, Action: 2, Price: 194.0, Shares: 84.0, Reward: -0.5822212416524071, Transaction Cost: 0.4957534416524139, Slippage: 0.06999999999999318, Time Penalty: 0.0164678
# Step: 223, Timestamp: 2023-07-03 08:09:44.674267162, Action: 2, Price: 194.0, Shares: 16.0, Reward: -0.49754065573566464, Transaction Cost: 0.4507736557356635, Slippage: 0.030000000000001137, Time Penalty: 0.016767
# Step: 224, Timestamp: 2023-07-03 08:09:44.674267162, Action: 1, Price: 194.0, Shares: 200.0, Reward: -0.1139643691127366, Transaction Cost: 0.06719736911273545, Slippage: 0.030000000000001137, Time Penalty: 0.016767
# Step: 228, Timestamp: 2023-07-03 08:09:44.674267162, Action: 1, Price: 194.0, Shares: 237.0, Reward: -0.30111378204301686, Transaction Cost: 0.25398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.0171316
# Step: 232, Timestamp: 2023-07-03 08:09:44.674366528, Action: 2, Price: 194.0, Shares: 223.0, Reward: -0.27231290125323754, Transaction Cost: 0.2257443012532364, Slippage: 0.030000000000001137, Time Penalty: 0.0165686
# Step: 233, Timestamp: 2023-07-03 08:09:44.674366528, Action: 2, Price: 194.0, Shares: 97.0, Reward: -0.14160003075502253, Transaction Cost: 0.09503143075502138, Slippage: 0.030000000000001137, Time Penalty: 0.0165686
# Step: 234, Timestamp: 2023-07-03 08:09:44.674366528, Action: 1, Price: 194.0, Shares: 250.0, Reward: -0.07196681820430272, Transaction Cost: 0.025398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.0165686
# Step: 237, Timestamp: 2023-07-03 08:09:57.033173375, Action: 2, Price: 193.98, Shares: 111.0, Reward: -0.09195301820431295, Transaction Cost: 0.025398218204301576, Slippage: 0.05000000000001137, Time Penalty: 0.0165548
# Step: 240, Timestamp: 2023-07-03 08:09:58.485383307, Action: 2, Price: 193.98, Shares: 199.0, Reward: -0.0933133424122012, Transaction Cost: 0.056792142412190966, Slippage: 0.020000000000010232, Time Penalty: 0.0165212
# Step: 241, Timestamp: 2023-07-03 08:10:23.350394016, Action: 2, Price: 193.97, Shares: 57.0, Reward: -0.37589314644634525, Transaction Cost: 0.35918504644634525, Slippage: 0.0, Time Penalty: 0.0167081
# Step: 263, Timestamp: 2023-07-03 08:11:08.479769664, Action: 1, Price: 193.96, Shares: 84.0, Reward: -0.1288522092892611, Transaction Cost: 0.07183700928926906, Slippage: 0.03999999999999204, Time Penalty: 0.0170152
# Step: 264, Timestamp: 2023-07-03 08:11:08.479769664, Action: 2, Price: 193.96, Shares: 84.0, Reward: -0.231100138225455, Transaction Cost: 0.1343947382254709, Slippage: 0.07999999999998408, Time Penalty: 0.0167054
# Step: 341, Timestamp: 2023-07-03 08:16:12.491633984, Action: 1, Price: 194.05, Shares: 67.0, Reward: -0.12865867497638864, Transaction Cost: 0.062212674976405695, Slippage: 0.04999999999998295, Time Penalty: 0.016446
# Step: 344, Timestamp: 2023-07-03 08:16:13.914513303, Action: 2, Price: 194.02, Shares: 67.0, Reward: -0.8484423985794632, Transaction Cost: 0.7820011985794803, Slippage: 0.04999999999998295, Time Penalty: 0.0164412
# Step: 418, Timestamp: 2023-07-03 08:20:36.512049191, Action: 1, Price: 193.83, Shares: 135.0, Reward: -0.3204239820429987, Transaction Cost: 0.25398218204301576, Slippage: 0.04999999999998295, Time Penalty: 0.0164418
# Step: 419, Timestamp: 2023-07-03 08:20:41.342172147, Action: 2, Price: 193.83, Shares: 135.0, Reward: -0.07184191820430272, Transaction Cost: 0.025398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.0164437
# Step: 435, Timestamp: 2023-07-03 08:22:05.585438246, Action: 1, Price: 193.81, Shares: 121.0, Reward: -0.22938829684498463, Transaction Cost: 0.1722590968449926, Slippage: 0.03999999999999204, Time Penalty: 0.0171292
# Step: 437, Timestamp: 2023-07-03 08:22:20.540108824, Action: 2, Price: 193.85, Shares: 121.0, Reward: -0.041853518204301575, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164553
# Step: 576, Timestamp: 2023-07-03 08:35:58.204200088, Action: 1, Price: 193.83, Shares: 60.0, Reward: -0.062213518204283384, Transaction Cost: 0.025398218204301576, Slippage: 0.01999999999998181, Time Penalty: 0.0168153
# Step: 577, Timestamp: 2023-07-03 08:35:58.204200088, Action: 2, Price: 193.83, Shares: 60.0, Reward: -0.15695311803554698, Transaction Cost: 0.08031621803554471, Slippage: 0.060000000000002274, Time Penalty: 0.0166369
# Step: 624, Timestamp: 2023-07-03 08:39:44.663825099, Action: 1, Price: 193.74, Shares: 234.0, Reward: -0.15695311803554698, Transaction Cost: 0.08031621803554471, Slippage: 0.060000000000002274, Time Penalty: 0.0166369
# Step: 626, Timestamp: 2023-07-03 08:39:44.675533651, Action: 2, Price: 193.73, Shares: 191.0, Reward: -0.27041768204301575, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0164355
# Step: 628, Timestamp: 2023-07-03 08:39:59.122781697, Action: 2, Price: 193.79, Shares: 43.0, Reward: -0.24780035751854518, Transaction Cost: 0.18137955751853382, Slippage: 0.05000000000001137, Time Penalty: 0.0164208
# Step: 634, Timestamp: 2023-07-03 08:41:25.524065449, Action: 1, Price: 193.8, Shares: 242.0, Reward: -0.05233990464463453, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0164214
# Step: 644, Timestamp: 2023-07-03 08:42:35.323211350, Action: 2, Price: 193.76, Shares: 224.0, Reward: -0.09687641803554471, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0165602
# Step: 645, Timestamp: 2023-07-03 08:43:22.001047613, Action: 2, Price: 193.76, Shares: 18.0, Reward: -0.09712461803554472, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0168084
# Step: 662, Timestamp: 2023-07-03 08:45:10.778573412, Action: 1, Price: 193.82, Shares: 70.0, Reward: -0.10801077804103226, Transaction Cost: 0.09157457804103226, Slippage: 0.0, Time Penalty: 0.0164362
# Step: 666, Timestamp: 2023-07-03 08:45:47.856592708, Action: 2, Price: 193.82, Shares: 70.0, Reward: -0.10233291820430385, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.0169347
# Step: 728, Timestamp: 2023-07-03 08:55:27.681246455, Action: 1, Price: 193.77, Shares: 182.0, Reward: -0.2665272232231658, Transaction Cost: 0.17959252322317262, Slippage: 0.06999999999999318, Time Penalty: 0.0169347
# Step: 731, Timestamp: 2023-07-03 08:56:01.005201521, Action: 2, Price: 193.77, Shares: 171.0, Reward: -0.3634977506154191, Transaction Cost: 0.27706185061542593, Slippage: 0.06999999999999318, Time Penalty: 0.0164359
# Step: 734, Timestamp: 2023-07-03 08:56:05.489716639, Action: 2, Price: 193.77, Shares: 11.0, Reward: -0.06742013640860316, Transaction Cost: 0.05079643640860315, Slippage: 0.0, Time Penalty: 0.0166237
# Step: 741, Timestamp: 2023-07-03 08:56:50.892676409, Action: 1, Price: 193.8, Shares: 122.0, Reward: -0.23119208151059856, Transaction Cost: 0.20476698151060765, Slippage: 0.009999999999990905, Time Penalty: 0.0164251
# Step: 746, Timestamp: 2023-07-03 08:57:08.555074132, Action: 2, Price: 193.76, Shares: 58.0, Reward: -0.23059901147433015, Transaction Cost: 0.17412141147430968, Slippage: 0.040000000000020464, Time Penalty: 0.0164776
# Step: 752, Timestamp: 2023-07-03 08:57:39.253074375, Action: 2, Price: 193.74, Shares: 64.0, Reward: -0.4189630825313478, Transaction Cost: 0.37241098253134663, Slippage: 0.030000000000001137, Time Penalty: 0.0165521
# Step: 807, Timestamp: 2023-07-03 09:05:37.388016341, Action: 1, Price: 193.7, Shares: 143.0, Reward: -0.11702201803555495, Transaction Cost: 0.08031621803554471, Slippage: 0.020000000000010232, Time Penalty: 0.0167058
# Step: 808, Timestamp: 2023-07-03 09:06:03.690550392, Action: 2, Price: 193.7, Shares: 143.0, Reward: -0.08851860928926907, Transaction Cost: 0.07183700928926906, Slippage: 0.0, Time Penalty: 0.0166816
# Step: 866, Timestamp: 2023-07-03 09:09:42.678593804, Action: 1, Price: 193.8, Shares: 145.0, Reward: -0.07184061820430271, Transaction Cost: 0.025398218204301576, Slippage: 0.030000000000001137, Time Penalty: 0.0164424
# Step: 871, Timestamp: 2023-07-03 09:10:53.284915451, Action: 2, Price: 193.79, Shares: 145.0, Reward: -0.14720281803552765, Transaction Cost: 0.08031621803554471, Slippage: 0.04999999999998295, Time Penalty: 0.0168866
# Step: 900, Timestamp: 2023-07-03 09:15:58.349438129, Action: 1, Price: 193.82, Shares: 219.0, Reward: -0.16669178524522119, Transaction Cost: 0.15025788524522118, Slippage: 0.0, Time Penalty: 0.0164339
# Step: 904, Timestamp: 2023-07-03 09:16:17.756194963, Action: 2, Price: 193.79, Shares: 219.0, Reward: -0.08730333640858497, Transaction Cost: 0.05079643640860315, Slippage: 0.01999999999998181, Time Penalty: 0.0165069
# Step: 979, Timestamp: 2023-07-03 09:30:16.768913671, Action: 1, Price: 193.78, Shares: 156.0, Reward: -0.10720591803553561, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0168897
# Step: 981, Timestamp: 2023-07-03 09:30:16.768913671, Action: 2, Price: 193.79, Shares: 69.0, Reward: -0.13914047550016448, Transaction Cost: 0.12180557550016448, Slippage: 0.0, Time Penalty: 0.0173349
# Step: 982, Timestamp: 2023-07-03 09:30:16.768913671, Action: 2, Price: 193.79, Shares: 87.0, Reward: -0.11218391820429476, Transaction Cost: 0.025398218204301576, Slippage: 0.06999999999999318, Time Penalty: 0.0167857
# Step: 1019, Timestamp: 2023-07-03 09:35:14.708705379, Action: 1, Price: 193.67, Shares: 157.0, Reward: -0.10814387804103226, Transaction Cost: 0.09157457804103226, Slippage: 0.0, Time Penalty: 0.0165693
# Step: 1023, Timestamp: 2023-07-03 09:35:38.362654286, Action: 2, Price: 193.65, Shares: 149.0, Reward: -0.05189121820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.016493
# Step: 1028, Timestamp: 2023-07-03 09:36:36.038520906, Action: 2, Price: 193.66, Shares: 8.0, Reward: -0.1180768728172063, Transaction Cost: 0.1015928728172063, Slippage: 0.0, Time Penalty: 0.016484
# Step: 1070, Timestamp: 2023-07-03 09:39:52.302331493, Action: 1, Price: 193.62, Shares: 196.0, Reward: -0.04183451820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164363
# Step: 1071, Timestamp: 2023-07-03 09:39:59.481640038, Action: 2, Price: 193.6, Shares: 196.0, Reward: -0.09222861820431294, Transaction Cost: 0.025398218204301576, Slippage: 0.05000000000001137, Time Penalty: 0.0168304
# Step: 1091, Timestamp: 2023-07-03 09:41:06.101724791, Action: 1, Price: 193.55, Shares: 251.0, Reward: -0.11703981803552653, Transaction Cost: 0.08031621803554471, Slippage: 0.01999999999998181, Time Penalty: 0.0167236
# Step: 1092, Timestamp: 2023-07-03 09:41:06.101724791, Action: 2, Price: 193.55, Shares: 174.0, Reward: -0.06212181820428339, Transaction Cost: 0.025398218204301576, Slippage: 0.01999999999998181, Time Penalty: 0.0167236
# Step: 1093, Timestamp: 2023-07-03 09:41:09.100383307, Action: 2, Price: 193.54, Shares: 77.0, Reward: -0.7834726072448613, Transaction Cost: 0.7469840072448796, Slippage: 0.01999999999998181, Time Penalty: 0.0164886
# Step: 1121, Timestamp: 2023-07-03 09:45:27.625041853, Action: 1, Price: 193.54, Shares: 236.0, Reward: -0.04184491820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164467
# Step: 1124, Timestamp: 2023-07-03 09:46:02.328977342, Action: 2, Price: 193.54, Shares: 176.0, Reward: -0.08324904241221029, Transaction Cost: 0.056792142412190966, Slippage: 0.010000000000019327, Time Penalty: 0.0164569
# Step: 1129, Timestamp: 2023-07-03 09:47:13.273616529, Action: 2, Price: 193.53, Shares: 59.0, Reward: -0.191235230029474, Transaction Cost: 0.15449133002946377, Slippage: 0.020000000000010232, Time Penalty: 0.0167439
# Step: 1131, Timestamp: 2023-07-03 09:48:10.913631406, Action: 2, Price: 193.54, Shares: 1.0, Reward: -0.19128421147430968, Transaction Cost: 0.17412141147430968, Slippage: 0.0, Time Penalty: 0.0171628
# Step: 1172, Timestamp: 2023-07-03 09:57:03.674346603, Action: 1, Price: 193.62, Shares: 154.0, Reward: -0.05308130464463453, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0171628
# Step: 1182, Timestamp: 2023-07-03 09:59:16.741257227, Action: 2, Price: 193.62, Shares: 101.0, Reward: -0.04185791820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164597
# Step: 1188, Timestamp: 2023-07-03 09:59:34.790243447, Action: 1, Price: 193.62, Shares: 83.0, Reward: -0.13001808482438193, Transaction Cost: 0.11358428482438193, Slippage: 0.0, Time Penalty: 0.0164338
# Step: 1191, Timestamp: 2023-07-03 10:00:12.996251499, Action: 2, Price: 193.58, Shares: 136.0, Reward: -0.3774961703093421, Transaction Cost: 0.13911177030934327, Slippage: 0.21999999999999886, Time Penalty: 0.0183844
# Step: 1253, Timestamp: 2023-07-03 10:04:57.609134588, Action: 1, Price: 193.51, Shares: 207.0, Reward: -0.2843029046446527, Transaction Cost: 0.03591850464463453, Slippage: 0.2300000000000182, Time Penalty: 0.0183844
# Step: 1255, Timestamp: 2023-07-03 10:04:59.311630768, Action: 2, Price: 193.51, Shares: 88.0, Reward: -0.4016270828331048, Transaction Cost: 0.2651651828331002, Slippage: 0.12000000000000455, Time Penalty: 0.0164619
# Step: 1266, Timestamp: 2023-07-03 10:05:19.772730461, Action: 2, Price: 193.5, Shares: 119.0, Reward: -0.20270095461288995, Transaction Cost: 0.07619465461290473, Slippage: 0.10999999999998522, Time Penalty: 0.0165063
# Step: 1277, Timestamp: 2023-07-03 10:05:21.240736312, Action: 1, Price: 193.46, Shares: 252.0, Reward: -0.10252221820430385, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.017124
# Step: 1278, Timestamp: 2023-07-03 10:05:21.240736312, Action: 2, Price: 193.45, Shares: 131.0, Reward: -0.1311150043515927, Transaction Cost: 0.04399100435157111, Slippage: 0.0700000000000216, Time Penalty: 0.017124
# Step: 1286, Timestamp: 2023-07-03 10:05:22.205252462, Action: 2, Price: 193.33, Shares: 74.0, Reward: -0.2319894182042993, Transaction Cost: 0.025398218204301576, Slippage: 0.18999999999999773, Time Penalty: 0.0165912
# Step: 1289, Timestamp: 2023-07-03 10:05:23.165747632, Action: 1, Price: 193.25, Shares: 55.0, Reward: -0.34706091803554473, Transaction Cost: 0.08031621803554471, Slippage: 0.25, Time Penalty: 0.0167447
# Step: 1292, Timestamp: 2023-07-03 10:05:26.614565469, Action: 2, Price: 193.37, Shares: 102.0, Reward: -0.16329369083771866, Transaction Cost: 0.13677359083772775, Slippage: 0.009999999999990905, Time Penalty: 0.0165201
# Step: 1395, Timestamp: 2023-07-03 10:10:05.523677172, Action: 1, Price: 193.41, Shares: 225.0, Reward: -0.09681631803554472, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0165001
# Step: 1398, Timestamp: 2023-07-03 10:10:24.346442517, Action: 2, Price: 193.4, Shares: 83.0, Reward: -0.11198931820429475, Transaction Cost: 0.025398218204301576, Slippage: 0.06999999999999318, Time Penalty: 0.0165911
# Step: 1403, Timestamp: 2023-07-03 10:10:48.160707870, Action: 2, Price: 193.4, Shares: 89.0, Reward: -0.11222711820429476, Transaction Cost: 0.025398218204301576, Slippage: 0.06999999999999318, Time Penalty: 0.0168289
# Step: 1405, Timestamp: 2023-07-03 10:10:48.160707870, Action: 2, Price: 193.4, Shares: 53.0, Reward: -0.09744103640860428, Transaction Cost: 0.05079643640860315, Slippage: 0.030000000000001137, Time Penalty: 0.0166446
# Step: 1422, Timestamp: 2023-07-03 10:12:47.831335542, Action: 1, Price: 193.41, Shares: 234.0, Reward: -0.11068716012723331, Transaction Cost: 0.08423636012724241, Slippage: 0.009999999999990905, Time Penalty: 0.0164508
# Step: 1428, Timestamp: 2023-07-03 10:12:49.886662629, Action: 2, Price: 193.4, Shares: 233.0, Reward: -0.08196441820429362, Transaction Cost: 0.025398218204301576, Slippage: 0.03999999999999204, Time Penalty: 0.0165662
# Step: 1430, Timestamp: 2023-07-03 10:12:49.968189516, Action: 2, Price: 193.4, Shares: 1.0, Reward: -0.12066206012722422, Transaction Cost: 0.08423636012724241, Slippage: 0.01999999999998181, Time Penalty: 0.0164257
# Step: 1432, Timestamp: 2023-07-03 10:12:49.973475345, Action: 1, Price: 193.4, Shares: 83.0, Reward: -0.12065676012722422, Transaction Cost: 0.08423636012724241, Slippage: 0.01999999999998181, Time Penalty: 0.0164204
# Step: 1436, Timestamp: 2023-07-03 10:12:49.984980515, Action: 2, Price: 193.4, Shares: 83.0, Reward: -0.18292585461290814, Transaction Cost: 0.07619465461290473, Slippage: 0.09000000000000341, Time Penalty: 0.0167312
# Step: 1449, Timestamp: 2023-07-03 10:12:50.008532686, Action: 1, Price: 193.35, Shares: 175.0, Reward: -0.15072220435157452, Transaction Cost: 0.04399100435157111, Slippage: 0.09000000000000341, Time Penalty: 0.0167312
# Step: 1450, Timestamp: 2023-07-03 10:12:51.665833818, Action: 2, Price: 193.41, Shares: 175.0, Reward: -0.04190701820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0165088
# Step: 1451, Timestamp: 2023-07-03 10:13:03.154145163, Action: 1, Price: 193.41, Shares: 228.0, Reward: -0.05245660464463453, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0165381
# Step: 1455, Timestamp: 2023-07-03 10:14:07.199237250, Action: 2, Price: 193.35, Shares: 174.0, Reward: -0.12245520464462771, Transaction Cost: 0.03591850464463453, Slippage: 0.06999999999999318, Time Penalty: 0.0165367
# Step: 1456, Timestamp: 2023-07-03 10:14:23.757868295, Action: 2, Price: 193.39, Shares: 54.0, Reward: -0.05187351820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0164753
# Step: 1469, Timestamp: 2023-07-03 10:17:08.236108828, Action: 1, Price: 193.42, Shares: 248.0, Reward: -0.04183431820430157, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164361
# Step: 1474, Timestamp: 2023-07-03 10:18:17.678286625, Action: 2, Price: 193.42, Shares: 166.0, Reward: -0.09193171820431295, Transaction Cost: 0.025398218204301576, Slippage: 0.05000000000001137, Time Penalty: 0.0165335
# Step: 1481, Timestamp: 2023-07-03 10:18:53.074844747, Action: 2, Price: 193.38, Shares: 56.0, Reward: -0.18726191803554815, Transaction Cost: 0.08031621803554471, Slippage: 0.09000000000000341, Time Penalty: 0.0169457
# Step: 1482, Timestamp: 2023-07-03 10:18:53.074844747, Action: 2, Price: 193.38, Shares: 26.0, Reward: -0.18675501803554811, Transaction Cost: 0.08031621803554471, Slippage: 0.09000000000000341, Time Penalty: 0.0164388
# Step: 1574, Timestamp: 2023-07-03 10:33:00.382598435, Action: 1, Price: 193.6, Shares: 58.0, Reward: -0.08366496911273545, Transaction Cost: 0.06719736911273545, Slippage: 0.0, Time Penalty: 0.0164676
# Step: 1576, Timestamp: 2023-07-03 10:33:44.211285377, Action: 2, Price: 193.59, Shares: 58.0, Reward: -0.12255071820431408, Transaction Cost: 0.025398218204301576, Slippage: 0.0800000000000125, Time Penalty: 0.0171525
# Step: 1605, Timestamp: 2023-07-03 10:39:15.554175119, Action: 1, Price: 193.48, Shares: 189.0, Reward: -0.2360370232231931, Transaction Cost: 0.17959252322317262, Slippage: 0.040000000000020464, Time Penalty: 0.0164445
# Step: 1606, Timestamp: 2023-07-03 10:39:22.461217838, Action: 2, Price: 193.47, Shares: 189.0, Reward: -0.36566936383871873, Transaction Cost: 0.22858396383871418, Slippage: 0.12000000000000455, Time Penalty: 0.0170854
# Step: 1620, Timestamp: 2023-07-03 10:40:08.271889530, Action: 1, Price: 193.47, Shares: 150.0, Reward: -0.04236231820430157, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0169641
# Step: 1625, Timestamp: 2023-07-03 10:42:04.566056878, Action: 2, Price: 193.46, Shares: 51.0, Reward: -0.04190501820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0165068
# Step: 1629, Timestamp: 2023-07-03 10:42:47.380907632, Action: 1, Price: 193.46, Shares: 161.0, Reward: -0.10727281803553562, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0169566
# Step: 1632, Timestamp: 2023-07-03 10:43:04.637124389, Action: 2, Price: 193.45, Shares: 88.0, Reward: -0.06193351820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0165353
# Step: 1635, Timestamp: 2023-07-03 10:43:34.842202344, Action: 2, Price: 193.44, Shares: 155.0, Reward: -0.04209731820430158, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0166991
# Step: 1646, Timestamp: 2023-07-03 10:45:35.938435949, Action: 2, Price: 193.46, Shares: 17.0, Reward: -0.22460452743011217, Transaction Cost: 0.17778752743011103, Slippage: 0.030000000000001137, Time Penalty: 0.016817
# Step: 1743, Timestamp: 2023-07-03 10:57:55.876549042, Action: 1, Price: 193.31, Shares: 62.0, Reward: -0.6243811241219016, Transaction Cost: 0.5679214241219096, Slippage: 0.03999999999999204, Time Penalty: 0.0164597
# Step: 1747, Timestamp: 2023-07-03 10:58:19.238550037, Action: 2, Price: 193.3, Shares: 62.0, Reward: -0.13356644241219323, Transaction Cost: 0.056792142412190966, Slippage: 0.060000000000002274, Time Penalty: 0.0167743
# Step: 1761, Timestamp: 2023-07-03 10:58:19.238996862, Action: 1, Price: 193.29, Shares: 68.0, Reward: -0.10217251820430384, Transaction Cost: 0.025398218204301576, Slippage: 0.060000000000002274, Time Penalty: 0.0167743
# Step: 1765, Timestamp: 2023-07-03 10:58:27.243338977, Action: 1, Price: 193.26, Shares: 249.0, Reward: -0.25647252322317493, Transaction Cost: 0.17959252322317262, Slippage: 0.060000000000002274, Time Penalty: 0.01688
# Step: 1766, Timestamp: 2023-07-03 10:58:27.243338977, Action: 2, Price: 193.26, Shares: 170.0, Reward: -0.2568827232231749, Transaction Cost: 0.17959252322317262, Slippage: 0.060000000000002274, Time Penalty: 0.0172902
# Step: 1772, Timestamp: 2023-07-03 10:58:27.244176300, Action: 2, Price: 193.25, Shares: 77.0, Reward: -0.2642071274301042, Transaction Cost: 0.17778752743011103, Slippage: 0.06999999999999318, Time Penalty: 0.0164196
# Step: 1774, Timestamp: 2023-07-03 10:58:28.969874749, Action: 2, Price: 193.25, Shares: 70.0, Reward: -0.06070660435157112, Transaction Cost: 0.04399100435157111, Slippage: 0.0, Time Penalty: 0.0167156
# Step: 1800, Timestamp: 2023-07-03 11:00:00.143811946, Action: 1, Price: 193.24, Shares: 111.0, Reward: -0.5668442435156963, Transaction Cost: 0.43991004351571106, Slippage: 0.10999999999998522, Time Penalty: 0.0169342
# Step: 1805, Timestamp: 2023-07-03 11:00:00.156307789, Action: 1, Price: 193.35, Shares: 223.0, Reward: -0.15838147281719833, Transaction Cost: 0.1015928728172063, Slippage: 0.03999999999999204, Time Penalty: 0.0167886
# Step: 1808, Timestamp: 2023-07-03 11:00:00.156307789, Action: 2, Price: 193.37, Shares: 155.0, Reward: -0.1318200307550032, Transaction Cost: 0.09503143075502138, Slippage: 0.01999999999998181, Time Penalty: 0.0167886
# Step: 1809, Timestamp: 2023-07-03 11:00:00.156355818, Action: 2, Price: 193.37, Shares: 124.0, Reward: -0.11673311803552652, Transaction Cost: 0.08031621803554471, Slippage: 0.01999999999998181, Time Penalty: 0.0164169
# Step: 1818, Timestamp: 2023-07-03 11:00:00.161078334, Action: 2, Price: 193.5, Shares: 55.0, Reward: -0.09718141803554471, Transaction Cost: 0.08031621803554471, Slippage: 0.0, Time Penalty: 0.0168652
# Step: 1842, Timestamp: 2023-07-03 11:00:00.448885763, Action: 1, Price: 193.44, Shares: 160.0, Reward: -0.2852680764509418, Transaction Cost: 0.2687894764509418, Slippage: 0.0, Time Penalty: 0.0164786
# Step: 1843, Timestamp: 2023-07-03 11:00:00.448919895, Action: 2, Price: 193.44, Shares: 54.0, Reward: -0.09276905461290473, Transaction Cost: 0.07619465461290473, Slippage: 0.0, Time Penalty: 0.0165744
# Step: 1844, Timestamp: 2023-07-03 11:00:00.448919895, Action: 2, Price: 193.45, Shares: 103.0, Reward: -0.1181672728172063, Transaction Cost: 0.1015928728172063, Slippage: 0.0, Time Penalty: 0.0165744
# Step: 1847, Timestamp: 2023-07-03 11:00:00.946625283, Action: 1, Price: 193.49, Shares: 57.0, Reward: -0.2216261307550066, Transaction Cost: 0.09503143075502138, Slippage: 0.10999999999998522, Time Penalty: 0.0165947
# Step: 1856, Timestamp: 2023-07-03 11:00:05.803122502, Action: 2, Price: 193.43, Shares: 60.0, Reward: -0.041906118204301575, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0165079
# Step: 1891, Timestamp: 2023-07-03 11:01:14.729278552, Action: 1, Price: 193.46, Shares: 150.0, Reward: -0.157081618035547, Transaction Cost: 0.08031621803554471, Slippage: 0.060000000000002274, Time Penalty: 0.0167654
# Step: 1893, Timestamp: 2023-07-03 11:01:33.502650401, Action: 2, Price: 193.5, Shares: 150.0, Reward: -0.22636082322317375, Transaction Cost: 0.17959252322317262, Slippage: 0.030000000000001137, Time Penalty: 0.0167683
# Step: 1939, Timestamp: 2023-07-03 11:03:12.821735900, Action: 1, Price: 193.5, Shares: 257.0, Reward: -0.13708451803553676, Transaction Cost: 0.08031621803554471, Slippage: 0.03999999999999204, Time Penalty: 0.0167683
# Step: 1940, Timestamp: 2023-07-03 11:03:12.821735900, Action: 2, Price: 193.5, Shares: 185.0, Reward: -0.13708451803553676, Transaction Cost: 0.08031621803554471, Slippage: 0.03999999999999204, Time Penalty: 0.0167683
# Step: 1942, Timestamp: 2023-07-03 11:03:33.733399227, Action: 2, Price: 193.54, Shares: 66.0, Reward: -0.4156810464463657, Transaction Cost: 0.35918504644634525, Slippage: 0.040000000000020464, Time Penalty: 0.016496
# Step: 1951, Timestamp: 2023-07-03 11:04:05.760166086, Action: 2, Price: 193.56, Shares: 6.0, Reward: -0.08240450464463567, Transaction Cost: 0.03591850464463453, Slippage: 0.030000000000001137, Time Penalty: 0.016486
# Step: 1952, Timestamp: 2023-07-03 11:04:33.083170546, Action: 1, Price: 193.58, Shares: 238.0, Reward: -0.8199166803554473, Transaction Cost: 0.8031621803554473, Slippage: 0.0, Time Penalty: 0.0167545
# Step: 1955, Timestamp: 2023-07-03 11:04:33.083247283, Action: 2, Price: 193.59, Shares: 238.0, Reward: -0.156792818035547, Transaction Cost: 0.08031621803554471, Slippage: 0.060000000000002274, Time Penalty: 0.0164766
# Step: 1992, Timestamp: 2023-07-03 11:05:58.196434906, Action: 1, Price: 193.41, Shares: 176.0, Reward: -0.1900738848243842, Transaction Cost: 0.11358428482438193, Slippage: 0.060000000000002274, Time Penalty: 0.0164896
# Step: 1996, Timestamp: 2023-07-03 11:06:16.644069472, Action: 1, Price: 193.46, Shares: 137.0, Reward: -0.14840030928927134, Transaction Cost: 0.07183700928926906, Slippage: 0.060000000000002274, Time Penalty: 0.0165633
# Step: 1999, Timestamp: 2023-07-03 11:06:16.644092112, Action: 2, Price: 193.49, Shares: 64.0, Reward: -0.21120346638366178, Transaction Cost: 0.16459926638366065, Slippage: 0.030000000000001137, Time Penalty: 0.0166042
# Step: 2001, Timestamp: 2023-07-03 11:06:18.989157268, Action: 2, Price: 193.52, Shares: 193.0, Reward: -0.12719061803554585, Transaction Cost: 0.08031621803554471, Slippage: 0.030000000000001137, Time Penalty: 0.0168744
# Step: 2004, Timestamp: 2023-07-03 11:06:18.989157268, Action: 1, Price: 193.55, Shares: 78.0, Reward: -0.3064586423785022, Transaction Cost: 0.28958424237850217, Slippage: 0.0, Time Penalty: 0.0168744
# Step: 2008, Timestamp: 2023-07-03 11:07:30.758704154, Action: 2, Price: 193.51, Shares: 134.0, Reward: -0.2124454174062947, Transaction Cost: 0.17596401740628445, Slippage: 0.020000000000010232, Time Penalty: 0.0164814
# Step: 2048, Timestamp: 2023-07-03 11:10:09.538361982, Action: 1, Price: 193.48, Shares: 133.0, Reward: -0.11712131803555495, Transaction Cost: 0.08031621803554471, Slippage: 0.020000000000010232, Time Penalty: 0.0168051
# Step: 2051, Timestamp: 2023-07-03 11:10:25.938517088, Action: 2, Price: 193.49, Shares: 123.0, Reward: -0.05188571820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0164875
# Step: 2052, Timestamp: 2023-07-03 11:10:29.556501620, Action: 2, Price: 193.49, Shares: 10.0, Reward: -0.2138781691127309, Transaction Cost: 0.06719736911273545, Slippage: 0.12999999999999545, Time Penalty: 0.0166808
# Step: 2073, Timestamp: 2023-07-03 11:12:05.406787626, Action: 1, Price: 193.45, Shares: 117.0, Reward: -0.43671987794433986, Transaction Cost: 0.3500902779443183, Slippage: 0.0700000000000216, Time Penalty: 0.0166296
# Step: 2079, Timestamp: 2023-07-03 11:12:22.326429914, Action: 2, Price: 193.44, Shares: 117.0, Reward: -0.24656952322315556, Transaction Cost: 0.17959252322317262, Slippage: 0.04999999999998295, Time Penalty: 0.016977
# Step: 2090, Timestamp: 2023-07-03 11:13:53.930047061, Action: 1, Price: 193.4, Shares: 59.0, Reward: -0.23735342723655584, Transaction Cost: 0.1703764272365729, Slippage: 0.04999999999998295, Time Penalty: 0.016977
# Step: 2094, Timestamp: 2023-07-03 11:14:10.835856023, Action: 1, Price: 193.45, Shares: 178.0, Reward: -0.21624942322318286, Transaction Cost: 0.17959252322317262, Slippage: 0.020000000000010232, Time Penalty: 0.0166569
# Step: 2099, Timestamp: 2023-07-03 11:14:13.077977719, Action: 2, Price: 193.45, Shares: 116.0, Reward: -0.2662408232231942, Transaction Cost: 0.17959252322317262, Slippage: 0.0700000000000216, Time Penalty: 0.0166483
# Step: 2100, Timestamp: 2023-07-03 11:14:13.077978226, Action: 2, Price: 193.45, Shares: 121.0, Reward: -0.174626088564086, Transaction Cost: 0.1480957885640667, Slippage: 0.010000000000019327, Time Penalty: 0.0165303
# Step: 2250, Timestamp: 2023-07-03 11:29:46.557275399, Action: 1, Price: 193.65, Shares: 159.0, Reward: -0.24617942322315556, Transaction Cost: 0.17959252322317262, Slippage: 0.04999999999998295, Time Penalty: 0.0165869
# Step: 2253, Timestamp: 2023-07-03 11:30:40.609578931, Action: 2, Price: 193.57, Shares: 151.0, Reward: -0.1973249664985388, Transaction Cost: 0.11070826649854565, Slippage: 0.06999999999999318, Time Penalty: 0.0166167
# Step: 2257, Timestamp: 2023-07-03 11:31:25.105672103, Action: 2, Price: 193.57, Shares: 8.0, Reward: -0.25813779419728533, Transaction Cost: 0.14141129419729104, Slippage: 0.09999999999999432, Time Penalty: 0.0167265
# Step: 2262, Timestamp: 2023-07-03 11:31:28.326612735, Action: 1, Price: 193.52, Shares: 89.0, Reward: -0.1524770182042868, Transaction Cost: 0.025398218204301576, Slippage: 0.10999999999998522, Time Penalty: 0.0170788
# Step: 2263, Timestamp: 2023-07-03 11:31:28.326612735, Action: 2, Price: 193.52, Shares: 89.0, Reward: -0.08237070464463567, Transaction Cost: 0.03591850464463453, Slippage: 0.030000000000001137, Time Penalty: 0.0164522
# ...
# Step: 6513, Timestamp: 2023-07-03 13:32:26.654624913, Action: 1, Price: 193.53, Shares: 1.0, Reward: -0.060424904351571114, Transaction Cost: 0.04399100435157111, Slippage: 0.0, Time Penalty: 0.0164339
# Step: 6517, Timestamp: 2023-07-03 13:32:27.890763596, Action: 1, Price: 193.51, Shares: 1.0, Reward: -0.05273581820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0173376
# Step: 6526, Timestamp: 2023-07-03 13:32:27.896380756, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.08412974241218188, Transaction Cost: 0.056792142412190966, Slippage: 0.009999999999990905, Time Penalty: 0.0173376
# Step: 6527, Timestamp: 2023-07-03 13:32:27.896380756, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.06364650464462543, Transaction Cost: 0.03591850464463453, Slippage: 0.009999999999990905, Time Penalty: 0.017728
# Step: 6536, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.15471909102149878, Transaction Cost: 0.12699109102150788, Slippage: 0.009999999999990905, Time Penalty: 0.017728
# Step: 6542, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.06503230464462544, Transaction Cost: 0.03591850464463453, Slippage: 0.009999999999990905, Time Penalty: 0.0191138
# Step: 6550, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.18974623607108032, Transaction Cost: 0.16063243607108943, Slippage: 0.009999999999990905, Time Penalty: 0.0191138
# Step: 6558, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.08718864241218187, Transaction Cost: 0.056792142412190966, Slippage: 0.009999999999990905, Time Penalty: 0.0203965
# Step: 6572, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.05710111820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0217029
# Step: 6575, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.13006977612859294, Transaction Cost: 0.09836687612860205, Slippage: 0.009999999999990905, Time Penalty: 0.0217029
# Step: 6577, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.08849504241218187, Transaction Cost: 0.056792142412190966, Slippage: 0.009999999999990905, Time Penalty: 0.0217029
# Step: 6578, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.05710111820429248, Transaction Cost: 0.025398218204301576, Slippage: 0.009999999999990905, Time Penalty: 0.0217029
# Step: 6585, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.21238792322316352, Transaction Cost: 0.17959252322317262, Slippage: 0.009999999999990905, Time Penalty: 0.0227954
# Step: 6591, Timestamp: 2023-07-03 13:32:27.896413823, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.14637968482437283, Transaction Cost: 0.11358428482438193, Slippage: 0.009999999999990905, Time Penalty: 0.0227954
# Step: 6596, Timestamp: 2023-07-03 13:32:27.896442734, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.23149640733819726, Transaction Cost: 0.20159210733820634, Slippage: 0.009999999999990905, Time Penalty: 0.0199043
# Step: 6600, Timestamp: 2023-07-03 13:32:27.896442734, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.07389530435156202, Transaction Cost: 0.04399100435157111, Slippage: 0.009999999999990905, Time Penalty: 0.0199043
# Step: 6601, Timestamp: 2023-07-03 13:32:27.896442734, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.16312341305470424, Transaction Cost: 0.13197301305471332, Slippage: 0.009999999999990905, Time Penalty: 0.0211504
# Step: 6607, Timestamp: 2023-07-03 13:32:27.896442734, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.14473468482437285, Transaction Cost: 0.11358428482438193, Slippage: 0.009999999999990905, Time Penalty: 0.0211504
# Step: 6609, Timestamp: 2023-07-03 13:32:27.896442734, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.21074292322316351, Transaction Cost: 0.17959252322317262, Slippage: 0.009999999999990905, Time Penalty: 0.0211504
# Step: 6613, Timestamp: 2023-07-03 13:32:27.896442734, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.08794254241218187, Transaction Cost: 0.056792142412190966, Slippage: 0.009999999999990905, Time Penalty: 0.0211504
# Step: 6614, Timestamp: 2023-07-03 13:32:27.896442734, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.10733661803553562, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0170204
# Step: 6617, Timestamp: 2023-07-03 13:32:27.896984494, Action: 2, Price: 193.49, Shares: 1.0, Reward: -0.05230711820432091, Transaction Cost: 0.025398218204301576, Slippage: 0.010000000000019327, Time Penalty: 0.0169089
# Step: 6621, Timestamp: 2023-07-03 13:32:27.897200212, Action: 1, Price: 193.48, Shares: 1.0, Reward: -0.10773601803553562, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0174198
# Step: 6638, Timestamp: 2023-07-03 13:32:27.911853167, Action: 1, Price: 193.47, Shares: 1.0, Reward: -0.07135480435156202, Transaction Cost: 0.04399100435157111, Slippage: 0.009999999999990905, Time Penalty: 0.0173638
# Step: 6642, Timestamp: 2023-07-03 13:32:27.911932438, Action: 2, Price: 193.47, Shares: 1.0, Reward: -0.20695632322316354, Transaction Cost: 0.17959252322317262, Slippage: 0.009999999999990905, Time Penalty: 0.0173638
# Step: 6643, Timestamp: 2023-07-03 13:32:27.911932438, Action: 1, Price: 193.47, Shares: 1.0, Reward: -0.10768001803553562, Transaction Cost: 0.08031621803554471, Slippage: 0.009999999999990905, Time Penalty: 0.0173638
# Step: 6645, Timestamp: 2023-07-03 13:32:27.911932438, Action: 1, Price: 193.47, Shares: 1.0, Reward: -0.041844118204301575, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0164459
# Step: 6652, Timestamp: 2023-07-03 13:32:27.916664415, Action: 1, Price: 193.48, Shares: 1.0, Reward: -0.06722923640860315, Transaction Cost: 0.05079643640860315, Slippage: 0.0, Time Penalty: 0.0164328
# Step: 6657, Timestamp: 2023-07-03 13:32:27.917044073, Action: 1, Price: 193.48, Shares: 1.0, Reward: -0.13278295743821736, Transaction Cost: 0.11638925743821735, Slippage: 0.0, Time Penalty: 0.0163937
# Step: 6661, Timestamp: 2023-07-03 13:32:27.917078895, Action: 1, Price: 193.48, Shares: 1.0, Reward: -0.2804659820430351, Transaction Cost: 0.25398218204301576, Slippage: 0.010000000000019327, Time Penalty: 0.0164838
# Step: 6666, Timestamp: 2023-07-03 13:32:28.072343618, Action: 2, Price: 193.46, Shares: 1.0, Reward: -0.5448449640860134, Transaction Cost: 0.5079643640860315, Slippage: 0.01999999999998181, Time Penalty: 0.0168806
# Step: 6669, Timestamp: 2023-07-03 13:32:28.072343618, Action: 1, Price: 193.46, Shares: 1.0, Reward: -0.16638661023420306, Transaction Cost: 0.12950601023422126, Slippage: 0.01999999999998181, Time Penalty: 0.0168806
# Step: 6670, Timestamp: 2023-07-03 13:32:28.072378449, Action: 1, Price: 193.46, Shares: 1.0, Reward: -0.26831643251244164, Transaction Cost: 0.25142953251244166, Slippage: 0.0, Time Penalty: 0.0168869
# Step: 6678, Timestamp: 2023-07-03 13:32:28.208064517, Action: 1, Price: 193.47, Shares: 1.0, Reward: -0.21793282723657403, Transaction Cost: 0.1703764272365729, Slippage: 0.030000000000001137, Time Penalty: 0.0175564
# Step: 6693, Timestamp: 2023-07-03 13:32:28.668551517, Action: 2, Price: 193.45, Shares: 1.0, Reward: -0.10955807497640682, Transaction Cost: 0.062212674976405695, Slippage: 0.030000000000001137, Time Penalty: 0.0173454
# Step: 6700, Timestamp: 2023-07-03 13:32:28.668557983, Action: 1, Price: 193.45, Shares: 1.0, Reward: -0.06260581820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0172076
# Step: 6708, Timestamp: 2023-07-03 13:32:28.668790859, Action: 1, Price: 193.44, Shares: 1.0, Reward: -0.06260581820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0172076
# Step: 6709, Timestamp: 2023-07-03 13:32:28.668790859, Action: 1, Price: 193.44, Shares: 1.0, Reward: -0.06229651820428339, Transaction Cost: 0.025398218204301576, Slippage: 0.01999999999998181, Time Penalty: 0.0168983
# Step: 6711, Timestamp: 2023-07-03 13:32:28.689845804, Action: 1, Price: 193.43, Shares: 1.0, Reward: -0.08769473640858497, Transaction Cost: 0.05079643640860315, Slippage: 0.01999999999998181, Time Penalty: 0.0168983
# Step: 6712, Timestamp: 2023-07-03 13:32:28.689845804, Action: 1, Price: 193.43, Shares: 1.0, Reward: -0.07328820464461634, Transaction Cost: 0.03591850464463453, Slippage: 0.01999999999998181, Time Penalty: 0.0173697
# Step: 6715, Timestamp: 2023-07-03 13:32:28.689845804, Action: 1, Price: 193.43, Shares: 1.0, Reward: -0.19393483194904004, Transaction Cost: 0.15656513194905822, Slippage: 0.01999999999998181, Time Penalty: 0.0173697
# Step: 6718, Timestamp: 2023-07-03 13:32:28.698534643, Action: 1, Price: 193.42, Shares: 1.0, Reward: -0.15327189083772774, Transaction Cost: 0.13677359083772775, Slippage: 0.0, Time Penalty: 0.0164983
# Step: 6721, Timestamp: 2023-07-03 13:32:29.032819884, Action: 1, Price: 193.43, Shares: 1.0, Reward: -0.08398386911273545, Transaction Cost: 0.06719736911273545, Slippage: 0.0, Time Penalty: 0.0167865
# Step: 6723, Timestamp: 2023-07-03 13:32:29.032820541, Action: 1, Price: 193.43, Shares: 1.0, Reward: -0.07271860464461634, Transaction Cost: 0.03591850464463453, Slippage: 0.01999999999998181, Time Penalty: 0.0168001
# Step: 6738, Timestamp: 2023-07-03 13:32:30.662208744, Action: 2, Price: 193.43, Shares: 1.0, Reward: -0.12103646012722422, Transaction Cost: 0.08423636012724241, Slippage: 0.01999999999998181, Time Penalty: 0.0168001
# Step: 6739, Timestamp: 2023-07-03 13:32:30.662208744, Action: 1, Price: 193.42, Shares: 1.0, Reward: -0.4167453464463373, Transaction Cost: 0.35918504644634525, Slippage: 0.03999999999999204, Time Penalty: 0.0175603
# Step: 6744, Timestamp: 2023-07-03 13:32:30.662208744, Action: 1, Price: 193.41, Shares: 1.0, Reward: -0.15259173075501342, Transaction Cost: 0.09503143075502138, Slippage: 0.03999999999999204, Time Penalty: 0.0175603
# Step: 6747, Timestamp: 2023-07-03 13:32:31.629494133, Action: 1, Price: 193.42, Shares: 1.0, Reward: -0.16042771857853813, Transaction Cost: 0.14367401857853812, Slippage: 0.0, Time Penalty: 0.0167537
# Step: 6756, Timestamp: 2023-07-03 13:32:33.243289410, Action: 1, Price: 193.42, Shares: 1.0, Reward: -0.16014698482438305, Transaction Cost: 0.11358428482438193, Slippage: 0.030000000000001137, Time Penalty: 0.0165627
# Step: 6759, Timestamp: 2023-07-03 13:32:33.686228566, Action: 1, Price: 193.41, Shares: 1.0, Reward: -0.290444382043026, Transaction Cost: 0.25398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0164622
# Step: 6762, Timestamp: 2023-07-03 13:32:35.338561366, Action: 1, Price: 193.42, Shares: 1.0, Reward: -0.12716841803554585, Transaction Cost: 0.08031621803554471, Slippage: 0.030000000000001137, Time Penalty: 0.0168522
# Step: 6768, Timestamp: 2023-07-03 13:32:35.575690444, Action: 1, Price: 193.4, Shares: 1.0, Reward: -0.35569235246077485, Transaction Cost: 0.3192506524607646, Slippage: 0.020000000000010232, Time Penalty: 0.0164417
# Step: 6789, Timestamp: 2023-07-03 13:32:35.920845395, Action: 1, Price: 193.39, Shares: 1.0, Reward: -0.27062168204301573, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0166395
# Step: 6792, Timestamp: 2023-07-03 13:32:36.202655867, Action: 1, Price: 193.39, Shares: 1.0, Reward: -0.04201391820430157, Transaction Cost: 0.025398218204301576, Slippage: 0.0, Time Penalty: 0.0166157
# Step: 6807, Timestamp: 2023-07-03 13:32:38.851973476, Action: 1, Price: 193.42, Shares: 1.0, Reward: -0.3544162160195398, Transaction Cost: 0.3379013160195398, Slippage: 0.0, Time Penalty: 0.0165149
# Step: 6812, Timestamp: 2023-07-03 13:32:39.787215191, Action: 1, Price: 193.42, Shares: 1.0, Reward: -0.12803117281722562, Transaction Cost: 0.1015928728172063, Slippage: 0.010000000000019327, Time Penalty: 0.0164383
# Step: 6814, Timestamp: 2023-07-03 13:32:40.112730105, Action: 2, Price: 193.42, Shares: 1.0, Reward: -0.10367406911271726, Transaction Cost: 0.06719736911273545, Slippage: 0.01999999999998181, Time Penalty: 0.0164767
# Step: 6816, Timestamp: 2023-07-03 13:32:41.750193535, Action: 1, Price: 193.41, Shares: 1.0, Reward: -0.0988757749763875, Transaction Cost: 0.062212674976405695, Slippage: 0.01999999999998181, Time Penalty: 0.0166631
# Step: 6820, Timestamp: 2023-07-03 13:32:41.997112772, Action: 1, Price: 193.4, Shares: 1.0, Reward: -0.21625562322315445, Transaction Cost: 0.17959252322317262, Slippage: 0.01999999999998181, Time Penalty: 0.0166631
# Step: 6822, Timestamp: 2023-07-03 13:32:42.750179698, Action: 1, Price: 193.39, Shares: 1.0, Reward: -0.11488597612860205, Transaction Cost: 0.09836687612860205, Slippage: 0.0, Time Penalty: 0.0165191
# Step: 6847, Timestamp: 2023-07-03 13:32:45.346289959, Action: 1, Price: 193.49, Shares: 1.0, Reward: -0.39561784644635545, Transaction Cost: 0.35918504644634525, Slippage: 0.020000000000010232, Time Penalty: 0.0164328
# Step: 6859, Timestamp: 2023-07-03 13:32:46.404860964, Action: 1, Price: 193.45, Shares: 1.0, Reward: -0.25515280587378086, Transaction Cost: 0.23825640587378089, Slippage: 0.0, Time Penalty: 0.0168964
# Step: 6872, Timestamp: 2023-07-03 13:32:48.956404192, Action: 1, Price: 193.49, Shares: 1.0, Reward: -0.27057068204301576, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0165885
# Step: 6878, Timestamp: 2023-07-03 13:32:49.081101992, Action: 1, Price: 193.52, Shares: 1.0, Reward: -0.14450871393388537, Transaction Cost: 0.10775551393390358, Slippage: 0.01999999999998181, Time Penalty: 0.0167532
# Step: 6890, Timestamp: 2023-07-03 13:32:50.006439950, Action: 1, Price: 193.52, Shares: 1.0, Reward: -0.28039198204303506, Transaction Cost: 0.25398218204301576, Slippage: 0.010000000000019327, Time Penalty: 0.0164098
# Step: 6899, Timestamp: 2023-07-03 13:32:52.914355688, Action: 1, Price: 193.46, Shares: 1.0, Reward: -0.1644933885640667, Transaction Cost: 0.1480957885640667, Slippage: 0.0, Time Penalty: 0.0163976
# Step: 6944, Timestamp: 2023-07-03 13:33:00.369469444, Action: 1, Price: 193.5, Shares: 1.0, Reward: -0.27045098204301576, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0164688
# Step: 6947, Timestamp: 2023-07-03 13:33:00.466400172, Action: 1, Price: 193.51, Shares: 1.0, Reward: -0.27050398204301573, Transaction Cost: 0.25398218204301576, Slippage: 0.0, Time Penalty: 0.0165218
# Step: 6954, Timestamp: 2023-07-03 13:33:00.492102711, Action: 1, Price: 193.53, Shares: 1.0, Reward: -0.052535604644634526, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0166171
# Step: 7010, Timestamp: 2023-07-03 13:33:05.375241671, Action: 1, Price: 193.51, Shares: 1.0, Reward: -0.05237410464463453, Transaction Cost: 0.03591850464463453, Slippage: 0.0, Time Penalty: 0.0164556
# Step: 7208, Timestamp: 2023-07-03 13:33:15.452111467, Action: 1, Price: 193.41, Shares: 1.0, Reward: -0.08385064241218187, Transaction Cost: 0.056792142412190966, Slippage: 0.009999999999990905, Time Penalty: 0.0170585
# Step: 7239, Timestamp: 2023-07-03 13:33:17.650793640, Action: 1, Price: 193.36, Shares: 1.0, Reward: -0.25897635991224777, Transaction Cost: 0.24228355991224776, Slippage: 0.0, Time Penalty: 0.0166928
# Step: 7484, Timestamp: 2023-07-03 13:33:32.629800481, Action: 1, Price: 193.2, Shares: 1.0, Reward: -0.06284771820431181, Transaction Cost: 0.025398218204301576, Slippage: 0.020000000000010232, Time Penalty: 0.0174495
# Step: 13211, Timestamp: 2023-07-03 13:46:18.374664839, Action: 1, Price: 193.0, Shares: 1.0, Reward: -0.08796374241218187, Transaction Cost: 0.056792142412190966, Slippage: 0.009999999999990905, Time Penalty: 0.0211716
# Step: 32823, Timestamp: 2023-07-03 14:46:15.178506162, Action: 1, Price: 192.0, Shares: 1.0, Reward: -0.19606192322317262, Transaction Cost: 0.17959252322317262, Slippage: 0.0, Time Penalty: 0.0164694

# %% [markdown]
# ### TRADING BLOTTER:

# %% [markdown]
# #### Preprocess the data for the trading blotter:

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

INITIAL_CASH = 10_000_000  # $10 million

def preprocess_data(df):
    df['liquidity'] = df['bid_sz_00'] * df['bid_px_00'] + df['ask_sz_00'] * df['ask_px_00']
    return df

def calculate_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_vol_and_liquidity(price_df, volume_df, window_size):
    # Calculate rolling statistics
    rolling_mean_vol = price_df.pct_change().rolling(window=window_size).mean()
    rolling_std_vol = price_df.pct_change().rolling(window=window_size).std()
    rolling_mean_liq = volume_df.rolling(window=window_size).mean()
    rolling_std_liq = volume_df.rolling(window=window_size).std()
    
    return rolling_mean_vol, rolling_std_vol, rolling_mean_liq, rolling_std_liq

def get_percentile(current_value, mean, std):
    if std > 0:
        z_score = (current_value - mean) / std
        percentile = norm.cdf(z_score)
    else:
        percentile = 0.5  # No variation
    return percentile

def get_trade_price(base_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction):
    vol_percentile = get_percentile(current_vol, mean_vol, std_vol)
    liq_percentile = get_percentile(current_liq, mean_liq, std_liq)

    # Define price adjustment scenarios based on market conditions
    if vol_percentile >= 0.9 and liq_percentile < 0.1:
        price_adjustment_percent = np.random.uniform(-0.25, -0.15)
    elif vol_percentile <= 0.1 and liq_percentile < 0.1:
        price_adjustment_percent = np.random.uniform(-0.10, -0.05)
    elif vol_percentile >= 0.9 and liq_percentile >= 0.9:
        price_adjustment_percent = np.random.uniform(-0.05, +0.10)
    else:
        price_adjustment_percent = np.random.uniform(-0.05, +0.05)  # Default for normal conditions

    # Adjust price based on trade direction
    if trade_direction == 'BUY':
        adjusted_price = base_price * (1 - price_adjustment_percent)
    else:  # SELL
        adjusted_price = base_price * (1 + price_adjustment_percent)
    
    return adjusted_price

# %% [markdown]
# #### Create trading environment for the blotter

# %%
class TradingEnvironmentwithBlotter:
    def __init__(self, data, daily_trading_limit, window_size):
        self.data = preprocess_data(data)
        self.daily_trading_limit = daily_trading_limit
        self.window_size = window_size
        self.state_columns = ['price', 'liquidity', 'RSI', 'MACD', 'MACD_signal', 'MACD_hist', 'Stoch_k', 'Stoch_d',
                              'OBV', 'Upper_BB', 'Middle_BB', 'Lower_BB', 'ATR_1', 'ADX', '+DI', '-DI', 'CCI']
        self.reset()

    def reset(self):
        self.current_step = 0
        self.balance = INITIAL_CASH
        self.shares_held = 0
        self.total_shares_traded = 0
        self.cumulative_reward = 0
        self.trades = []
        self.portfolio = {'cash': self.balance, 'holdings': {ticker: 0 for ticker in self.data['symbol'].unique()}}
        self.data['RSI'] = calculate_rsi(self.data['price'])
        self.data['pct_change'] = self.data['price'].pct_change()
        self.data['rolling_mean_vol'], self.data['rolling_std_vol'], self.data['rolling_mean_liq'], self.data['rolling_std_liq'] = calculate_vol_and_liquidity(self.data['price'], self.data['liquidity'], self.window_size)

    def step(self):
        row = self.data.iloc[self.current_step]
        current_price = row['price']
        current_time = pd.to_datetime(row['ts_event'])
        current_rsi = row['RSI']
        current_vol = row['pct_change']
        current_liq = row['liquidity']
        mean_vol = row['rolling_mean_vol']
        std_vol = row['rolling_std_vol']
        mean_liq = row['rolling_mean_liq']
        std_liq = row['rolling_std_liq']

        if current_rsi < 30:  # Entry signal based on RSI
            trade_direction = 'BUY'
            trade_price = get_trade_price(current_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction)
            trade_size = (self.portfolio['cash'] * np.random.uniform(0.001, 0.005)) / trade_price
            if self.portfolio['cash'] >= trade_size * trade_price:
                self.portfolio['cash'] -= trade_size * trade_price
                self.portfolio['holdings'][row['symbol']] += trade_size
                trade_status = 'filled'
            else:
                trade_status = 'cancelled'
        elif current_rsi > 70:  # Exit signal based on RSI
            trade_direction = 'SELL'
            if self.portfolio['holdings'][row['symbol']] > 0:
                trade_size = min(self.portfolio['holdings'][row['symbol']], self.portfolio['cash']*np.random.uniform(0.001, 0.005) / current_price)
                trade_price = get_trade_price(current_price, current_vol, current_liq, mean_vol, std_vol, mean_liq, std_liq, trade_direction)
                self.portfolio['cash'] += trade_size * trade_price
                self.portfolio['holdings'][row['symbol']] -= trade_size
                trade_status = 'filled'
            else:
                trade_size = 0
                trade_status = 'cancelled'
        else:
            trade_direction = 'HOLD'
            trade_size = 0
            trade_price = current_price
            trade_status = 'skipped'

        if trade_size > 0:
            expected_price = row['ask_px_00']
            actual_price = row['price']
            transaction_time = row['ts_in_delta']
            transaction_cost = self._calculate_transaction_cost(row['Volume'], 0.3, self.data['Volume'].mean())
            slippage = expected_price - actual_price
            time_penalty = 1000 * transaction_time / 1e9
            reward = - (slippage + time_penalty + transaction_cost)
        
            self.cumulative_reward += reward
            self.trades.append({
                'step': self.current_step,
                'timestamp': current_time,
                'action': trade_direction,
                'price': trade_price,
                'shares': trade_size,
                'symbol': row['symbol'],
                'reward': reward,
                'transaction_cost': transaction_cost,
                'slippage': slippage,
                'time_penalty': time_penalty
            })

            

        self.current_step += 1
        if self.current_step >= len(self.data) - 1:
            done=True
            self.current_step = 0

    def _calculate_transaction_cost(self, volume, volatility, daily_volume):
        return volatility * np.sqrt(volume / daily_volume)

    def run(self):
        self.reset()
        for _ in range(len(self.data)):
            self.step()
        return self.cumulative_reward, self.trades

    def render(self):
        print(f'Cumulative reward: {self.cumulative_reward}')
        row = self.data.iloc[self.current_step]
        print(f'Total portfolio value: {self.portfolio["cash"] + self.portfolio["holdings"][row["symbol"]]*row["Close"]}')
        # get trades in a pandas dataframe
        trades_df = pd.DataFrame(self.trades)
        # Save a csv
        trades_df.to_csv('trades_blotter.csv', index=False)
        for trade in self.trades:
            print(f"Step: {trade['step']}, Timestamp: {trade['timestamp']}, Action: {trade['action']}, Price: {trade['price']}, Shares: {trade['shares']}, Symbol: {trade['symbol']}, Reward: {trade['reward']}, Transaction Cost: {trade['transaction_cost']}, Slippage: {trade['slippage']}, Time Penalty: {trade['time_penalty']}")

# %% [markdown]
# #### Run the trading blotter

# %%
# Filter data for the specified ticker
ticker = 'AAPL'  # Specify the ticker you want to trade
ticker_data = market_features_df[market_features_df['symbol'] == ticker]

window_size = 60
daily_trading_limit = 1000
# Create the trading environment
env = TradingEnvironmentwithBlotter(ticker_data, daily_trading_limit=1000, window_size=window_size)  # Daily trading limit of 1000 shares

# Run the environment
cumulative_reward, trades = env.run()

# Render the results
env.render()
# Out:
# Cumulative reward: -12231.228875703917
# Total portfolio value: 10020834.05992944
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df=market_features_df.copy()

# %%
df['timestamp']=pd.to_datetime(df['ts_recv'])

# %%
df.head()
# Out:
#                 ts_recv             ts_event  rtype  publisher_id  \
# 35  1688371214386057385  1688371214385893078      1             2
# 36  1688371214386063777  1688371214385899379      1             2
# 37  1688371215804852019  1688371215804687301      1             2
# 38  1688371219671476629  1688371219671312224      1             2
# 39  1688371223368835585  1688371223368671235      1             2
#
#     instrument_id action side  depth   price  size  flags  ts_in_delta  \
# 35             32      T    N      0  194.05    50    130       164307
# 36             32      T    N      0  194.05    50    130       164398
# 37             32      T    B      0  194.21    10    130       164718
# 38             32      T    N      0  194.14    10    130       164405
# 39             32      T    B      0  194.13    10    130       164350
#
#     sequence  bid_px_00  ask_px_00  bid_sz_00  ask_sz_00  bid_ct_00  \
# 35    326232      194.0     194.30       3101         19          4
# 36    326233      194.0     194.30       3101         19          4
# 37    328131      194.0     194.21       3101         29          4
# 38    331406      194.0     194.16       3101        400          4
# 39    334235      194.0     194.13       3101        400          4
#
#     ask_ct_00 symbol   Close  Volume    High    Low    Open        RSI  \
# 35         10   AAPL  194.05      50  194.30  194.0  194.05  54.544543
# 36         10   AAPL  194.05      50  194.30  194.0  194.05  54.544543
# 37          1   AAPL  194.21      10  194.21  194.0  194.05  85.890753
# 38          1   AAPL  194.14      10  194.16  194.0  194.21  64.827662
# 39          1   AAPL  194.13      10  194.13  194.0  194.14  62.470772
#
#         MACD  MACD_signal  MACD_hist    Stoch_k    Stoch_d    OBV    Upper_BB  \
# 35  0.006271    -0.003130   0.009401  52.525253  61.952862 -266.0  194.065621
# 36  0.007108    -0.001082   0.008190  38.383838  52.525253 -266.0  194.068990
# 37  0.020446     0.003223   0.017223  40.404040  43.771044 -256.0  194.125889
# 38  0.025079     0.007594   0.017484  49.494949  42.760943 -266.0  194.142928
# 39  0.027625     0.011601   0.016025  57.575758  49.158249 -276.0  194.155247
#
#     Middle_BB    Lower_BB  ATR_1     ATR_2     ATR_5    ATR_10    ATR_20  \
# 35   194.0170  193.968379   0.30  0.175078  0.098615  0.075141  0.072403
# 36   194.0200  193.971010   0.30  0.237539  0.138892  0.097627  0.083783
# 37   194.0305  193.935111   0.21  0.223770  0.153114  0.108864  0.090094
# 38   194.0375  193.932072   0.21  0.216885  0.164491  0.118978  0.096089
# 39   194.0440  193.932753   0.14  0.178442  0.159593  0.121080  0.098285
#
#           ADX        +DI       -DI         CCI       DLR        TWAP  \
# 35  97.257397  30.435801  0.196362  166.666667  0.000000  194.020000
# 36  97.361721  22.989295  0.148320   83.333333  0.000000  194.020811
# 37  97.458593  19.409454  0.125224   79.268293  0.000824  194.025789
# 38  97.548546  16.622008  0.107240   -3.205128 -0.000360  194.028718
# 39  97.632074  15.068361  0.097216 -113.095238 -0.000052  194.031250
#
#           VWAP                     timestamp
# 35  194.021894 2023-07-03 08:00:14.386057385
# 36  194.025188 2023-07-03 08:00:14.386063777
# 37  194.025596 2023-07-03 08:00:15.804852019
# 38  194.025873 2023-07-03 08:00:19.671476629
# 39  194.026071 2023-07-03 08:00:23.368835585
